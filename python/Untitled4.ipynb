# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python executable path: {sys.executable}")
# Out:
# Python version: 3.12.11 (main, Jun  6 2025, 23:18:08) [Clang 16.0.0 (clang-1600.0.26.6)]
# Python executable path: /opt/local/Library/Frameworks/Python.framework/Versions/3.12/bin/python3.12

# %%
# Method 1: Using pip
# !port list | grep python
# Out:
# dbus-python                    @1.3.2          devel/dbus-python
# dbus-python27                  @1.2.18         devel/dbus-python
# dbus-python35                  @1.3.2          devel/dbus-python
# dbus-python37                  @1.3.2          devel/dbus-python
# dbus-python36                  @1.3.2          devel/dbus-python
# dbus-python38                  @1.3.2          devel/dbus-python
# dbus-python39                  @1.3.2          devel/dbus-python
# dbus-python310                 @1.3.2          devel/dbus-python
# dbus-python311                 @1.3.2          devel/dbus-python
# dbus-python312                 @1.3.2          devel/dbus-python
# dbus-python313                 @1.3.2          devel/dbus-python
# gnome-bindings-python          @2.32.1         devel/gnome-bindings-python
# micropython                    @1.25.0         devel/micropython
# mpy-cross                      @1.25.0         devel/micropython
# subversion-python27bindings    @1.13.0         devel/subversion-python27bindings
# subversion-pythonbindings      @1.14.3         devel/subversion-pythonbindings
# subversion-pythonbindings-3.8  @1.14.3         devel/subversion-pythonbindings
# subversion-pythonbindings-3.9  @1.14.3         devel/subversion-pythonbindings
# subversion-pythonbindings-3.10 @1.14.3         devel/subversion-pythonbindings
# subversion-pythonbindings-3.11 @1.14.3         devel/subversion-pythonbindings
# subversion-pythonbindings-3.12 @1.14.3         devel/subversion-pythonbindings
# swig-python                    @4.3.1          devel/swig
# swig3-python                   @3.0.12         devel/swig3
# tree-sitter-python             @0.23.6         devel/tree-sitter-python
# xapian-bindings-python38       @1.4.27         devel/xapian-core
# xapian-bindings-python39       @1.4.27         devel/xapian-core
# xapian-bindings-python310      @1.4.27         devel/xapian-core
# xapian-bindings-python311      @1.4.27         devel/xapian-core
# xapian-bindings-python312      @1.4.27         devel/xapian-core
# xapian-bindings-python313      @1.4.27         devel/xapian-core
# gpython                        @0.2.0          lang/gpython
# lpython                        @0.20.0         lang/lpython
# python-mode.el                 @1.0            lang/python-mode.el
# python26                       @2.6.9          lang/python26
# python27                       @2.7.18         lang/python27
# python310                      @3.10.18        lang/python310
# python311                      @3.11.13        lang/python311
# python312                      @3.12.11        lang/python312
# python313                      @3.13.5         lang/python313
# python313-devel                @3.13.0rc3      lang/python313-devel
# python27-bootstrap             @2.7.18         lang/python27
# python313-freethreading        @3.13.5         lang/python313
# python314-devel                @3.14.0b2       lang/python314-devel
# python32                       @3.2.6          lang/python32
# python33                       @3.3.7          lang/python33
# python34                       @3.4.10         lang/python34
# python35                       @3.5.10         lang/python35
# python36                       @3.6.15         lang/python36
# python37                       @3.7.17         lang/python37
# python38                       @3.8.20         lang/python38
# python39                       @3.9.23         lang/python39
# qore-python-module             @1.2.0          lang/qore-python-module
# rustpython                     @0.4.0          lang/rustpython
# cl-pythonic-string-reader      @20180618       lisp/cl-pythonic-string-reader
# youtube-search-python          @1.6.6          net/youtube-search-python
# octave-pythonic                @0.1.3          octave/octave-pythonic
# p5-inline-python               @0.560.0        perl/p5-inline-python
# p5.28-inline-python            @0.560.0        perl/p5-inline-python
# p5.30-inline-python            @0.560.0        perl/p5-inline-python
# p5.32-inline-python            @0.560.0        perl/p5-inline-python
# p5.34-inline-python            @0.560.0        perl/p5-inline-python
# ansible_select                 @0.1            python/ansible_select
# autopep8_select                @0.1            python/autopep8_select
# awscli_select                  @0.3            python/awscli_select
# bandit                         @1.7.8          python/bandit
# black_select                   @0.1            python/black_select
# bpython_select                 @0.15           python/bpython_select
# buildout_select                @0.1            python/buildout_select
# buku                           @5.0            python/buku
# celery_select                  @0.1            python/celery_select
# codespell                      @2.4.1          python/codespell
# csvkit_select                  @0.1            python/csvkit_select
# cython_select                  @0.1            python/cython_select
# django-htmlmin_select          @0.9.2          python/django-htmlmin_select
# docker-compose                 @1.29.2         python/docker-compose
# docutils_select                @0.2            python/docutils_select
# dot2tex                        @2.11.3         python/dot2tex
# doxyqml                        @0.5.3          python/doxyqml
# epy                            @2023.6.11      python/epy
# fabric_select                  @0.1            python/fabric_select
# fava                           @1.27.3         python/fava
# fdsnwsscripts_select           @1.0            python/fdsnwsscripts_select
# flake8_select                  @0.1            python/flake8_select
# flynt                          @1.0.2          python/flynt
# fonttools_select               @0.1            python/fonttools_select
# gdal_select                    @0.1            python/gdal_select
# github-backup                  @0.36.0         python/github-backup
# gpilab_select                  @0.1            python/gpilab_select
# gzdice                         @0.1.2          python/gzdice
# hatch                          @1.14.1         python/hatch
# hatchling_select               @0.1            python/hatchling_select
# hieroglyph_select              @0.1            python/hieroglyph_select
# honcho_select                  @0.1            python/honcho_select
# httpx_select                   @0.1            python/httpx_select
# hy_select                      @0.1            python/hy_select
# hyfetch                        @1.99.0         python/hyfetch
# impressive                     @0.13.2         python/impressive
# internetarchive                @5.4.0          python/internetarchive
# ioflo_select                   @0.1            python/ioflo_select
# ipdb_select                    @0.3            python/ipdb_select
# ipython2_select                @0.1            python/ipython2_select
# ipython3_select                @0.1            python/ipython3_select
# ipython_select                 @0.4            python/ipython_select
# isort_select                   @0.1            python/isort_select
# jupyter_select                 @0.1            python/jupyter_select
# kerfi-vangasvipur_select       @1.0            python/kerfi-vangasvipur_select
# lexicon_select                 @0.1            python/lexicon_select
# local-pipelines_select         @0.1            python/local-pipelines_select
# logcat-color3                  @0.10.0         python/logcat-color3
# memprof_select                 @0.1            python/memprof_select
# morshutalk                     @0.0.2          python/morshutalk
# mypy_select                    @0.1            python/mypy_select
# ninja-ide                      @2.4            python/ninja-ide
# nosetests_select               @0.1            python/nosetests_select
# obspy_select                   @1.0            python/obspy_select
# panel_select                   @0.1            python/panel_select
# pep8_select                    @0.1            python/pep8_select
# pew_select                     @0.1            python/pew_select
# pip_select                     @0.1            python/pip_select
# pipenv                         @2024.4.0       python/pipenv
# pipx                           @1.7.1          python/pipx
# podman-compose                 @1.3.0          python/podman-compose
# poetry                         @2.0.1          python/poetry
# pre-commit                     @4.2.0          python/pre-commit
# present                        @0.6.0          python/present
# ptpython_select                @0.1            python/ptpython_select
# py-BitArray2D                  @2.1            python/py-BitArray2D
# py-BitVector                   @3.5.0          python/py-BitVector
# py-DAWG                        @0.8.0          python/py-DAWG
# podman-compose-devel           @2025-04-14     python/podman-compose
# py312-BitArray2D               @2.1            python/py-BitArray2D
# py312-BitVector                @3.5.0          python/py-BitVector
# py-Faker                       @30.8.1         python/py-Faker
# py-GridDataFormats             @0.6.0          python/py-GridDataFormats
# py-LabJackPython               @2.1.0          python/py-LabJackPython
# py-MDAnalysis                  @2.0.0          python/py-MDAnalysis
# py-Pillow                      @9.5.0          python/py-Pillow
# py-Pyro5                       @5.15           python/py-Pyro5
# py-SDL2                        @0.9.17         python/py-SDL2
# py-XlsxWriter                  @3.2.3          python/py-XlsxWriter
# py38-DAWG                      @0.8.0          python/py-DAWG
# py39-Faker                     @30.8.1         python/py-Faker
# py310-Faker                    @30.8.1         python/py-Faker
# py311-Faker                    @30.8.1         python/py-Faker
# py312-Faker                    @30.8.1         python/py-Faker
# py39-GridDataFormats           @0.6.0          python/py-GridDataFormats
# py312-LabJackPython            @2.1.0          python/py-LabJackPython
# py39-MDAnalysis                @2.0.0          python/py-MDAnalysis
# py27-Pillow                    @6.2.2          python/py-Pillow
# py39-Pillow                    @9.5.0          python/py-Pillow
# py310-Pillow                   @9.5.0          python/py-Pillow
# py311-Pillow                   @9.5.0          python/py-Pillow
# py312-Pillow                   @9.5.0          python/py-Pillow
# py313-Pillow                   @9.5.0          python/py-Pillow
# py39-Pyro5                     @5.15           python/py-Pyro5
# py310-Pyro5                    @5.15           python/py-Pyro5
# py311-Pyro5                    @5.15           python/py-Pyro5
# py312-Pyro5                    @5.15           python/py-Pyro5
# py27-SDL2                      @0.9.17         python/py-SDL2
# py38-SDL2                      @0.9.17         python/py-SDL2
# py39-SDL2                      @0.9.17         python/py-SDL2
# py310-SDL2                     @0.9.17         python/py-SDL2
# py311-SDL2                     @0.9.17         python/py-SDL2
# py312-SDL2                     @0.9.17         python/py-SDL2
# py313-SDL2                     @0.9.17         python/py-SDL2
# py39-XlsxWriter                @3.2.3          python/py-XlsxWriter
# py310-XlsxWriter               @3.2.3          python/py-XlsxWriter
# py311-XlsxWriter               @3.2.3          python/py-XlsxWriter
# py312-XlsxWriter               @3.2.3          python/py-XlsxWriter
# py313-XlsxWriter               @3.2.3          python/py-XlsxWriter
# py-about-time                  @4.2.1          python/py-about-time
# py-absl                        @2.1.0          python/py-absl
# py-access                      @1.1.9          python/py-access
# py-acefile                     @0.6.12         python/py-acefile
# py-acme                        @4.1.1          python/py-acme
# py-acor                        @1.1.1          python/py-acor
# py-acora                       @2.5            python/py-acora
# py-acoustid                    @1.3.0          python/py-acoustid
# py-actdiag                     @3.0.0          python/py-actdiag
# py-aenum                       @3.1.15         python/py-aenum
# py-aeppl                       @0.1.5          python/py-aeppl
# py-aesara                      @2.9.4          python/py-aesara
# py39-about-time                @4.2.1          python/py-about-time
# py310-about-time               @4.2.1          python/py-about-time
# py311-about-time               @4.2.1          python/py-about-time
# py312-about-time               @4.2.1          python/py-about-time
# py39-absl                      @2.1.0          python/py-absl
# py310-absl                     @2.1.0          python/py-absl
# py311-absl                     @2.1.0          python/py-absl
# py312-absl                     @2.1.0          python/py-absl
# py39-access                    @1.1.9          python/py-access
# py310-access                   @1.1.9          python/py-access
# py311-access                   @1.1.9          python/py-access
# py312-access                   @1.1.9          python/py-access
# py313-access                   @1.1.9          python/py-access
# py39-acefile                   @0.6.12         python/py-acefile
# py310-acefile                  @0.6.12         python/py-acefile
# py39-acme                      @4.1.1          python/py-acme
# py310-acme                     @4.1.1          python/py-acme
# py311-acme                     @4.1.1          python/py-acme
# py312-acme                     @4.1.1          python/py-acme
# py313-acme                     @4.1.1          python/py-acme
# py311-acor                     @1.1.1          python/py-acor
# py312-acor                     @1.1.1          python/py-acor
# py313-acor                     @1.1.1          python/py-acor
# py39-acora                     @2.5            python/py-acora
# py310-acora                    @2.5            python/py-acora
# py311-acora                    @2.5            python/py-acora
# py312-acora                    @2.5            python/py-acora
# py39-acoustid                  @1.3.0          python/py-acoustid
# py310-acoustid                 @1.3.0          python/py-acoustid
# py311-acoustid                 @1.3.0          python/py-acoustid
# py312-acoustid                 @1.3.0          python/py-acoustid
# py39-actdiag                   @3.0.0          python/py-actdiag
# py310-actdiag                  @3.0.0          python/py-actdiag
# py39-aenum                     @3.1.15         python/py-aenum
# py310-aenum                    @3.1.15         python/py-aenum
# py311-aenum                    @3.1.15         python/py-aenum
# py39-aeppl                     @0.1.5          python/py-aeppl
# py310-aeppl                    @0.1.5          python/py-aeppl
# py311-aeppl                    @0.1.5          python/py-aeppl
# py312-aeppl                    @0.1.5          python/py-aeppl
# py39-aesara                    @2.9.4          python/py-aesara
# py310-aesara                   @2.9.4          python/py-aesara
# py311-aesara                   @2.9.4          python/py-aesara
# py312-aesara                   @2.9.4          python/py-aesara
# py-affine                      @2.4.0          python/py-affine
# py-agate                       @1.6.3          python/py-agate
# py-agate-dbf                   @0.2.2          python/py-agate-dbf
# py-agate-excel                 @0.2.5          python/py-agate-excel
# py-agate-sql                   @0.5.8          python/py-agate-sql
# py-aiobotocore                 @2.21.1         python/py-aiobotocore
# py-aiodns                      @3.4.0          python/py-aiodns
# py-aiofiles                    @24.1.0         python/py-aiofiles
# py-aioftp                      @0.25.2         python/py-aioftp
# py-aiohappyeyeballs            @2.6.1          python/py-aiohappyeyeballs
# py-aiohttp                     @3.11.18        python/py-aiohttp
# py-aiohttp-socks               @0.10.1         python/py-aiohttp-socks
# py39-affine                    @2.4.0          python/py-affine
# py310-affine                   @2.4.0          python/py-affine
# py311-affine                   @2.4.0          python/py-affine
# py312-affine                   @2.4.0          python/py-affine
# py313-affine                   @2.4.0          python/py-affine
# py39-agate                     @1.6.3          python/py-agate
# py310-agate                    @1.6.3          python/py-agate
# py311-agate                    @1.6.3          python/py-agate
# py312-agate                    @1.6.3          python/py-agate
# py313-agate                    @1.6.3          python/py-agate
# py39-agate-dbf                 @0.2.2          python/py-agate-dbf
# py310-agate-dbf                @0.2.2          python/py-agate-dbf
# py311-agate-dbf                @0.2.2          python/py-agate-dbf
# py312-agate-dbf                @0.2.2          python/py-agate-dbf
# py313-agate-dbf                @0.2.2          python/py-agate-dbf
# py39-agate-excel               @0.2.5          python/py-agate-excel
# py310-agate-excel              @0.2.5          python/py-agate-excel
# py311-agate-excel              @0.2.5          python/py-agate-excel
# py312-agate-excel              @0.2.5          python/py-agate-excel
# py313-agate-excel              @0.2.5          python/py-agate-excel
# py39-agate-sql                 @0.5.8          python/py-agate-sql
# py310-agate-sql                @0.5.8          python/py-agate-sql
# py311-agate-sql                @0.5.8          python/py-agate-sql
# py312-agate-sql                @0.5.8          python/py-agate-sql
# py313-agate-sql                @0.5.8          python/py-agate-sql
# py39-aiobotocore               @2.21.1         python/py-aiobotocore
# py311-aiobotocore              @2.21.1         python/py-aiobotocore
# py312-aiobotocore              @2.21.1         python/py-aiobotocore
# py313-aiobotocore              @2.21.1         python/py-aiobotocore
# py39-aiodns                    @3.4.0          python/py-aiodns
# py310-aiodns                   @3.4.0          python/py-aiodns
# py311-aiodns                   @3.4.0          python/py-aiodns
# py312-aiodns                   @3.4.0          python/py-aiodns
# py313-aiodns                   @3.4.0          python/py-aiodns
# py39-aiofiles                  @24.1.0         python/py-aiofiles
# py310-aiofiles                 @24.1.0         python/py-aiofiles
# py311-aiofiles                 @24.1.0         python/py-aiofiles
# py312-aiofiles                 @24.1.0         python/py-aiofiles
# py313-aiofiles                 @24.1.0         python/py-aiofiles
# py39-aioftp                    @0.25.2         python/py-aioftp
# py310-aioftp                   @0.25.2         python/py-aioftp
# py311-aioftp                   @0.25.2         python/py-aioftp
# py312-aioftp                   @0.25.2         python/py-aioftp
# py313-aioftp                   @0.25.2         python/py-aioftp
# py39-aiohappyeyeballs          @2.6.1          python/py-aiohappyeyeballs
# py310-aiobotocore              @2.21.1         python/py-aiobotocore
# py310-aiohappyeyeballs         @2.6.1          python/py-aiohappyeyeballs
# py311-aiohappyeyeballs         @2.6.1          python/py-aiohappyeyeballs
# py312-aiohappyeyeballs         @2.6.1          python/py-aiohappyeyeballs
# py313-aiohappyeyeballs         @2.6.1          python/py-aiohappyeyeballs
# py39-aiohttp                   @3.11.18        python/py-aiohttp
# py310-aiohttp                  @3.11.18        python/py-aiohttp
# py311-aiohttp                  @3.11.18        python/py-aiohttp
# py312-aiohttp                  @3.11.18        python/py-aiohttp
# py313-aiohttp                  @3.11.18        python/py-aiohttp
# py39-aiohttp-socks             @0.10.1         python/py-aiohttp-socks
# py310-aiohttp-socks            @0.10.1         python/py-aiohttp-socks
# py311-aiohttp-socks            @0.10.1         python/py-aiohttp-socks
# py312-aiohttp-socks            @0.10.1         python/py-aiohttp-socks
# py313-aiohttp-socks            @0.10.1         python/py-aiohttp-socks
# py-aioitertools                @0.12.0         python/py-aioitertools
# py-aiojobs                     @1.4.0          python/py-aiojobs
# py-aiomysql                    @0.2.0          python/py-aiomysql
# py-aiopg                       @1.4.0          python/py-aiopg
# py-aioquic                     @1.2.0          python/py-aioquic
# py-aiorpcX                     @0.22.1         python/py-aiorpcX
# py-aiosignal                   @1.3.2          python/py-aiosignal
# py-aiosmtpd                    @1.4.6          python/py-aiosmtpd
# py-aiosqlite                   @0.21.0         python/py-aiosqlite
# py-alabaster                   @1.0.0          python/py-alabaster
# py-alagitpull                  @0.1.0          python/py-alagitpull
# py-alembic                     @1.13.3         python/py-alembic
# py39-aioitertools              @0.12.0         python/py-aioitertools
# py310-aioitertools             @0.12.0         python/py-aioitertools
# py311-aioitertools             @0.12.0         python/py-aioitertools
# py312-aioitertools             @0.12.0         python/py-aioitertools
# py313-aioitertools             @0.12.0         python/py-aioitertools
# py39-aiojobs                   @1.4.0          python/py-aiojobs
# py310-aiojobs                  @1.4.0          python/py-aiojobs
# py311-aiojobs                  @1.4.0          python/py-aiojobs
# py312-aiojobs                  @1.4.0          python/py-aiojobs
# py313-aiojobs                  @1.4.0          python/py-aiojobs
# py39-aiomysql                  @0.2.0          python/py-aiomysql
# py310-aiomysql                 @0.2.0          python/py-aiomysql
# py39-aiopg                     @1.4.0          python/py-aiopg
# py310-aiopg                    @1.4.0          python/py-aiopg
# py39-aioquic                   @1.2.0          python/py-aioquic
# py310-aioquic                  @1.2.0          python/py-aioquic
# py311-aioquic                  @1.2.0          python/py-aioquic
# py312-aioquic                  @1.2.0          python/py-aioquic
# py313-aioquic                  @1.2.0          python/py-aioquic
# py312-aiorpcX                  @0.22.1         python/py-aiorpcX
# py39-aiosignal                 @1.3.2          python/py-aiosignal
# py310-aiosignal                @1.3.2          python/py-aiosignal
# py311-aiosignal                @1.3.2          python/py-aiosignal
# py312-aiosignal                @1.3.2          python/py-aiosignal
# py313-aiosignal                @1.3.2          python/py-aiosignal
# py39-aiosmtpd                  @1.4.6          python/py-aiosmtpd
# py39-aiosqlite                 @0.21.0         python/py-aiosqlite
# py310-aiosqlite                @0.21.0         python/py-aiosqlite
# py311-aiosqlite                @0.21.0         python/py-aiosqlite
# py312-aiosqlite                @0.21.0         python/py-aiosqlite
# py27-alabaster                 @0.7.12         python/py-alabaster
# py37-alabaster                 @0.7.13         python/py-alabaster
# py311-alabaster                @1.0.0          python/py-alabaster
# py313-aiosqlite                @0.21.0         python/py-aiosqlite
# py36-alabaster                 @0.7.13         python/py-alabaster
# py38-alabaster                 @0.7.13         python/py-alabaster
# py39-alabaster                 @0.7.16         python/py-alabaster
# py310-alabaster                @1.0.0          python/py-alabaster
# py312-alabaster                @1.0.0          python/py-alabaster
# py313-alabaster                @1.0.0          python/py-alabaster
# py39-alagitpull                @0.1.0          python/py-alagitpull
# py310-alagitpull               @0.1.0          python/py-alagitpull
# py311-alagitpull               @0.1.0          python/py-alagitpull
# py312-alagitpull               @0.1.0          python/py-alagitpull
# py39-alembic                   @1.13.3         python/py-alembic
# py310-alembic                  @1.13.3         python/py-alembic
# py311-alembic                  @1.13.3         python/py-alembic
# py312-alembic                  @1.13.3         python/py-alembic
# py-algopy                      @0.7.2          python/py-algopy
# py-alive-progress              @3.2.0          python/py-alive-progress
# py-allennlp                    @2.4.0          python/py-allennlp
# py-altair                      @5.5.0          python/py-altair
# py-altgraph                    @0.17.4         python/py-altgraph
# py-amqp                        @5.2.0          python/py-amqp
# py-analytics-python            @1.4.0          python/py-analytics-python
# py-aniso8601                   @10.0.1         python/py-aniso8601
# py-annotated_types             @0.7.0          python/py-annotated_types
# py-annoy                       @1.17.3         python/py-annoy
# py-ansible                     @11.1.0         python/py-ansible
# py-ansible-compat              @24.10.0        python/py-ansible-compat
# py39-algopy                    @0.7.2          python/py-algopy
# py310-algopy                   @0.7.2          python/py-algopy
# py311-algopy                   @0.7.2          python/py-algopy
# py312-algopy                   @0.7.2          python/py-algopy
# py313-algopy                   @0.7.2          python/py-algopy
# py39-alive-progress            @3.2.0          python/py-alive-progress
# py310-alive-progress           @3.2.0          python/py-alive-progress
# py311-alive-progress           @3.2.0          python/py-alive-progress
# py312-alive-progress           @3.2.0          python/py-alive-progress
# py39-allennlp                  @2.4.0          python/py-allennlp
# py39-altair                    @5.5.0          python/py-altair
# py310-altair                   @5.5.0          python/py-altair
# py311-altair                   @5.5.0          python/py-altair
# py312-altair                   @5.5.0          python/py-altair
# py313-altair                   @5.5.0          python/py-altair
# py27-altgraph                  @0.17.4         python/py-altgraph
# py37-altgraph                  @0.17.4         python/py-altgraph
# py38-altgraph                  @0.17.4         python/py-altgraph
# py39-altgraph                  @0.17.4         python/py-altgraph
# py310-altgraph                 @0.17.4         python/py-altgraph
# py311-altgraph                 @0.17.4         python/py-altgraph
# py312-altgraph                 @0.17.4         python/py-altgraph
# py313-altgraph                 @0.17.4         python/py-altgraph
# py39-amqp                      @5.2.0          python/py-amqp
# py310-amqp                     @5.2.0          python/py-amqp
# py311-amqp                     @5.2.0          python/py-amqp
# py312-amqp                     @5.2.0          python/py-amqp
# py39-analytics-python          @1.4.0          python/py-analytics-python
# py310-analytics-python         @1.4.0          python/py-analytics-python
# py39-aniso8601                 @10.0.1         python/py-aniso8601
# py310-aniso8601                @10.0.1         python/py-aniso8601
# py311-aniso8601                @10.0.1         python/py-aniso8601
# py312-aniso8601                @10.0.1         python/py-aniso8601
# py39-annotated_types           @0.7.0          python/py-annotated_types
# py313-aniso8601                @10.0.1         python/py-aniso8601
# py310-annotated_types          @0.7.0          python/py-annotated_types
# py311-annotated_types          @0.7.0          python/py-annotated_types
# py312-annotated_types          @0.7.0          python/py-annotated_types
# py313-annotated_types          @0.7.0          python/py-annotated_types
# py312-annoy                    @1.17.3         python/py-annoy
# py39-ansible                   @11.1.0         python/py-ansible
# py310-ansible                  @11.1.0         python/py-ansible
# py311-ansible                  @11.1.0         python/py-ansible
# py312-ansible                  @11.1.0         python/py-ansible
# py313-ansible                  @11.1.0         python/py-ansible
# py39-ansible-compat            @24.10.0        python/py-ansible-compat
# py310-ansible-compat           @24.10.0        python/py-ansible-compat
# py311-ansible-compat           @24.10.0        python/py-ansible-compat
# py312-ansible-compat           @24.10.0        python/py-ansible-compat
# py313-ansible-compat           @24.10.0        python/py-ansible-compat
# py-ansible-core                @2.18.1         python/py-ansible-core
# py-ansicolor                   @0.3.2          python/py-ansicolor
# py-antlr4-python3-runtime      @4.13.1         python/py-antlr4-python3-runtime
# py-anyio                       @4.9.0          python/py-anyio
# py-anyjson                     @0.3.3          python/py-anyjson
# py-anytree                     @2.13.0         python/py-anytree
# py-apache-beam                 @2.29.0         python/py-apache-beam
# py-apipkg                      @3.0.2          python/py-apipkg
# py-aplpy                       @1.1.1          python/py-aplpy
# py-app-model                   @0.3.1          python/py-app-model
# py-appdirs                     @1.4.4          python/py-appdirs
# py-applaunchservices           @0.3.0          python/py-applaunchservices
# py39-ansible-core              @2.18.1         python/py-ansible-core
# py310-ansible-core             @2.18.1         python/py-ansible-core
# py311-ansible-core             @2.18.1         python/py-ansible-core
# py312-ansible-core             @2.18.1         python/py-ansible-core
# py313-ansible-core             @2.18.1         python/py-ansible-core
# py39-ansicolor                 @0.3.2          python/py-ansicolor
# py39-antlr4-python3-runtime    @4.13.1         python/py-antlr4-python3-runtime
# py310-antlr4-python3-runtime   @4.13.1         python/py-antlr4-python3-runtime
# py311-antlr4-python3-runtime   @4.13.1         python/py-antlr4-python3-runtime
# py312-antlr4-python3-runtime   @4.13.1         python/py-antlr4-python3-runtime
# py39-anyio                     @4.9.0          python/py-anyio
# py310-anyio                    @4.9.0          python/py-anyio
# py311-anyio                    @4.9.0          python/py-anyio
# py312-anyio                    @4.9.0          python/py-anyio
# py313-anyio                    @4.9.0          python/py-anyio
# py39-anyjson                   @0.3.3          python/py-anyjson
# py310-anyjson                  @0.3.3          python/py-anyjson
# py39-anytree                   @2.13.0         python/py-anytree
# py310-anytree                  @2.13.0         python/py-anytree
# py311-anytree                  @2.13.0         python/py-anytree
# py312-anytree                  @2.13.0         python/py-anytree
# py313-anytree                  @2.13.0         python/py-anytree
# py39-apache-beam               @2.29.0         python/py-apache-beam
# py39-apipkg                    @3.0.2          python/py-apipkg
# py39-aplpy                     @1.1.1          python/py-aplpy
# py39-app-model                 @0.3.1          python/py-app-model
# py313-app-model                @0.3.1          python/py-app-model
# py310-apipkg                   @3.0.2          python/py-apipkg
# py310-app-model                @0.3.1          python/py-app-model
# py311-app-model                @0.3.1          python/py-app-model
# py312-app-model                @0.3.1          python/py-app-model
# py38-appdirs                   @1.4.4          python/py-appdirs
# py39-appdirs                   @1.4.4          python/py-appdirs
# py310-appdirs                  @1.4.4          python/py-appdirs
# py311-appdirs                  @1.4.4          python/py-appdirs
# py312-appdirs                  @1.4.4          python/py-appdirs
# py313-appdirs                  @1.4.4          python/py-appdirs
# py39-applaunchservices         @0.3.0          python/py-applaunchservices
# py310-applaunchservices        @0.3.0          python/py-applaunchservices
# py311-applaunchservices        @0.3.0          python/py-applaunchservices
# py312-applaunchservices        @0.3.0          python/py-applaunchservices
# py313-applaunchservices        @0.3.0          python/py-applaunchservices
# py-applescript                 @1.0.3          python/py-applescript
# py-appnope                     @0.1.4          python/py-appnope
# py-appscript                   @1.2.2          python/py-appscript
# py-apptools                    @5.3.0          python/py-apptools
# py-apsw                        @3.44.0.0       python/py-apsw
# py-arabic-reshaper             @3.0.0          python/py-arabic-reshaper
# py-argcomplete                 @3.6.2          python/py-argcomplete
# py-argh                        @0.31.3         python/py-argh
# py-argon2-cffi                 @23.1.0         python/py-argon2-cffi
# py-argon2-cffi-bindings        @21.2.0         python/py-argon2-cffi-bindings
# py-arpeggio                    @2.0.2          python/py-arpeggio
# py-arrow                       @1.3.0          python/py-arrow
# py39-applescript               @1.0.3          python/py-applescript
# py310-applescript              @1.0.3          python/py-applescript
# py311-applescript              @1.0.3          python/py-applescript
# py312-applescript              @1.0.3          python/py-applescript
# py313-applescript              @1.0.3          python/py-applescript
# py39-appnope                   @0.1.4          python/py-appnope
# py310-appnope                  @0.1.4          python/py-appnope
# py311-appnope                  @0.1.4          python/py-appnope
# py312-appnope                  @0.1.4          python/py-appnope
# py313-appnope                  @0.1.4          python/py-appnope
# py39-appscript                 @1.2.2          python/py-appscript
# py310-appscript                @1.2.2          python/py-appscript
# py39-apptools                  @5.3.0          python/py-apptools
# py310-apptools                 @5.3.0          python/py-apptools
# py311-apptools                 @5.3.0          python/py-apptools
# py312-apptools                 @5.3.0          python/py-apptools
# py39-apsw                      @3.44.0.0       python/py-apsw
# py310-apsw                     @3.44.0.0       python/py-apsw
# py311-apsw                     @3.44.0.0       python/py-apsw
# py39-arabic-reshaper           @3.0.0          python/py-arabic-reshaper
# py310-arabic-reshaper          @3.0.0          python/py-arabic-reshaper
# py311-arabic-reshaper          @3.0.0          python/py-arabic-reshaper
# py312-arabic-reshaper          @3.0.0          python/py-arabic-reshaper
# py39-argcomplete               @3.6.2          python/py-argcomplete
# py310-argcomplete              @3.6.2          python/py-argcomplete
# py311-argcomplete              @3.6.2          python/py-argcomplete
# py312-argcomplete              @3.6.2          python/py-argcomplete
# py313-argcomplete              @3.6.2          python/py-argcomplete
# py27-argh                      @0.27.2         python/py-argh
# py39-argh                      @0.31.3         python/py-argh
# py310-argh                     @0.31.3         python/py-argh
# py311-argh                     @0.31.3         python/py-argh
# py312-argh                     @0.31.3         python/py-argh
# py313-argh                     @0.31.3         python/py-argh
# py39-argon2-cffi               @23.1.0         python/py-argon2-cffi
# py310-argon2-cffi              @23.1.0         python/py-argon2-cffi
# py311-argon2-cffi              @23.1.0         python/py-argon2-cffi
# py312-argon2-cffi              @23.1.0         python/py-argon2-cffi
# py313-argon2-cffi              @23.1.0         python/py-argon2-cffi
# py39-argon2-cffi-bindings      @21.2.0         python/py-argon2-cffi-bindings
# py310-argon2-cffi-bindings     @21.2.0         python/py-argon2-cffi-bindings
# py311-argon2-cffi-bindings     @21.2.0         python/py-argon2-cffi-bindings
# py312-argon2-cffi-bindings     @21.2.0         python/py-argon2-cffi-bindings
# py313-argon2-cffi-bindings     @21.2.0         python/py-argon2-cffi-bindings
# py39-arpeggio                  @2.0.2          python/py-arpeggio
# py310-arpeggio                 @2.0.2          python/py-arpeggio
# py311-arpeggio                 @2.0.2          python/py-arpeggio
# py312-arpeggio                 @2.0.2          python/py-arpeggio
# py313-arpeggio                 @2.0.2          python/py-arpeggio
# py39-arrow                     @1.3.0          python/py-arrow
# py310-arrow                    @1.3.0          python/py-arrow
# py311-arrow                    @1.3.0          python/py-arrow
# py312-arrow                    @1.3.0          python/py-arrow
# py313-arrow                    @1.3.0          python/py-arrow
# py-arviz                       @0.21.0         python/py-arviz
# py-asciimatics                 @1.15.0         python/py-asciimatics
# py-asdf                        @4.2.0          python/py-asdf
# py-asdf-astropy                @0.8.0          python/py-asdf-astropy
# py-asdf-coordinates-schemas    @0.4.0          python/py-asdf-coordinates-schemas
# py-asdf-standard               @1.3.0          python/py-asdf-standard
# py-asdf-transform-schemas      @0.6.0          python/py-asdf-transform-schemas
# py-asdf-unit-schemas           @0.2.0          python/py-asdf-unit-schemas
# py-asgiref                     @3.8.1          python/py-asgiref
# py-asn1                        @0.6.1          python/py-asn1
# py-asn1-modules                @0.4.0          python/py-asn1-modules
# py-asn1crypto                  @1.5.1          python/py-asn1crypto
# py310-arviz                    @0.21.0         python/py-arviz
# py311-arviz                    @0.21.0         python/py-arviz
# py312-arviz                    @0.21.0         python/py-arviz
# py313-arviz                    @0.21.0         python/py-arviz
# py39-asciimatics               @1.15.0         python/py-asciimatics
# py310-asciimatics              @1.15.0         python/py-asciimatics
# py311-asciimatics              @1.15.0         python/py-asciimatics
# py39-asdf                      @4.2.0          python/py-asdf
# py310-asdf                     @4.2.0          python/py-asdf
# py311-asdf                     @4.2.0          python/py-asdf
# py312-asdf                     @4.2.0          python/py-asdf
# py313-asdf                     @4.2.0          python/py-asdf
# py39-asdf-astropy              @0.8.0          python/py-asdf-astropy
# py310-asdf-astropy             @0.8.0          python/py-asdf-astropy
# py311-asdf-astropy             @0.8.0          python/py-asdf-astropy
# py312-asdf-astropy             @0.8.0          python/py-asdf-astropy
# py313-asdf-astropy             @0.8.0          python/py-asdf-astropy
# py39-asdf-coordinates-schemas  @0.4.0          python/py-asdf-coordinates-schemas
# py310-asdf-coordinates-schemas @0.4.0          python/py-asdf-coordinates-schemas
# py311-asdf-coordinates-schemas @0.4.0          python/py-asdf-coordinates-schemas
# py312-asdf-coordinates-schemas @0.4.0          python/py-asdf-coordinates-schemas
# py313-asdf-coordinates-schemas @0.4.0          python/py-asdf-coordinates-schemas
# py39-asdf-standard             @1.3.0          python/py-asdf-standard
# py310-asdf-standard            @1.3.0          python/py-asdf-standard
# py311-asdf-standard            @1.3.0          python/py-asdf-standard
# py312-asdf-standard            @1.3.0          python/py-asdf-standard
# py313-asdf-standard            @1.3.0          python/py-asdf-standard
# py39-asdf-transform-schemas    @0.6.0          python/py-asdf-transform-schemas
# py310-asdf-transform-schemas   @0.6.0          python/py-asdf-transform-schemas
# py311-asdf-transform-schemas   @0.6.0          python/py-asdf-transform-schemas
# py312-asdf-transform-schemas   @0.6.0          python/py-asdf-transform-schemas
# py313-asdf-transform-schemas   @0.6.0          python/py-asdf-transform-schemas
# py39-asdf-unit-schemas         @0.2.0          python/py-asdf-unit-schemas
# py310-asdf-unit-schemas        @0.2.0          python/py-asdf-unit-schemas
# py311-asdf-unit-schemas        @0.2.0          python/py-asdf-unit-schemas
# py312-asdf-unit-schemas        @0.2.0          python/py-asdf-unit-schemas
# py313-asdf-unit-schemas        @0.2.0          python/py-asdf-unit-schemas
# py39-asgiref                   @3.8.1          python/py-asgiref
# py311-asgiref                  @3.8.1          python/py-asgiref
# py312-asgiref                  @3.8.1          python/py-asgiref
# py313-asgiref                  @3.8.1          python/py-asgiref
# py27-asn1                      @0.5.1          python/py-asn1
# py39-asn1                      @0.6.1          python/py-asn1
# py311-asn1                     @0.6.1          python/py-asn1
# py312-asn1                     @0.6.1          python/py-asn1
# py311-asn1-modules             @0.4.0          python/py-asn1-modules
# py310-asgiref                  @3.8.1          python/py-asgiref
# py310-asn1                     @0.6.1          python/py-asn1
# py313-asn1                     @0.6.1          python/py-asn1
# py27-asn1-modules              @0.3.0          python/py-asn1-modules
# py39-asn1-modules              @0.4.0          python/py-asn1-modules
# py310-asn1-modules             @0.4.0          python/py-asn1-modules
# py312-asn1-modules             @0.4.0          python/py-asn1-modules
# py313-asn1-modules             @0.4.0          python/py-asn1-modules
# py39-asn1crypto                @1.5.1          python/py-asn1crypto
# py310-asn1crypto               @1.5.1          python/py-asn1crypto
# py311-asn1crypto               @1.5.1          python/py-asn1crypto
# py312-asn1crypto               @1.5.1          python/py-asn1crypto
# py313-asn1crypto               @1.5.1          python/py-asn1crypto
# py-asteval                     @1.0.6          python/py-asteval
# py-astlib                      @0.10.1         python/py-astlib
# py-astor                       @0.8.1          python/py-astor
# py-astroML                     @0.4.1          python/py-astroML
# py-astroML_addons              @0.2.2          python/py-astroML_addons
# py-astroid                     @3.3.10         python/py-astroid
# py-astroplan                   @0.7            python/py-astroplan
# py-astropy                     @7.1.0          python/py-astropy
# py-astropy-healpix             @0.6            python/py-astropy-healpix
# py-astropy-helpers             @4.0.1          python/py-astropy-helpers
# py-astroquery                  @0.4.6          python/py-astroquery
# py39-asteval                   @1.0.6          python/py-asteval
# py310-asteval                  @1.0.6          python/py-asteval
# py311-asteval                  @1.0.6          python/py-asteval
# py312-asteval                  @1.0.6          python/py-asteval
# py313-asteval                  @1.0.6          python/py-asteval
# py39-astlib                    @0.10.1         python/py-astlib
# py39-astor                     @0.8.1          python/py-astor
# py310-astor                    @0.8.1          python/py-astor
# py311-astor                    @0.8.1          python/py-astor
# py312-astor                    @0.8.1          python/py-astor
# py313-astor                    @0.8.1          python/py-astor
# py39-astroML                   @0.4.1          python/py-astroML
# py39-astroML_addons            @0.2.2          python/py-astroML_addons
# py39-astroid                   @3.3.10         python/py-astroid
# py310-astroid                  @3.3.10         python/py-astroid
# py311-astroid                  @3.3.10         python/py-astroid
# py312-astroid                  @3.3.10         python/py-astroid
# py313-astroid                  @3.3.10         python/py-astroid
# py39-astroplan                 @0.7            python/py-astroplan
# py39-astropy                   @6.1.6          python/py-astropy
# py310-astropy                  @6.1.6          python/py-astropy
# py311-astropy                  @7.1.0          python/py-astropy
# py313-astropy                  @7.1.0          python/py-astropy
# py312-astropy                  @7.1.0          python/py-astropy
# py39-astropy-healpix           @0.6            python/py-astropy-healpix
# py310-astropy-healpix          @0.6            python/py-astropy-healpix
# py39-astropy-helpers           @4.0.1          python/py-astropy-helpers
# py310-astropy-helpers          @4.0.1          python/py-astropy-helpers
# py39-astroquery                @0.4.6          python/py-astroquery
# py310-astroquery               @0.4.6          python/py-astroquery
# py311-astroquery               @0.4.6          python/py-astroquery
# py-astroscrappy                @1.0.5          python/py-astroscrappy
# py-asttokens                   @3.0.0          python/py-asttokens
# py-astunparse                  @1.6.3          python/py-astunparse
# py39-astroscrappy              @1.0.5          python/py-astroscrappy
# py39-asttokens                 @3.0.0          python/py-asttokens
# py310-asttokens                @3.0.0          python/py-asttokens
# py311-asttokens                @3.0.0          python/py-asttokens
# py312-asttokens                @3.0.0          python/py-asttokens
# py313-asttokens                @3.0.0          python/py-asttokens
# py-asv                         @0.6.4          python/py-asv
# py-asv-runner                  @0.2.1          python/py-asv-runner
# py-async-lru                   @2.0.5          python/py-async-lru
# py-async-timeout               @4.0.3          python/py-async-timeout
# py39-astunparse                @1.6.3          python/py-astunparse
# py310-astunparse               @1.6.3          python/py-astunparse
# py311-astunparse               @1.6.3          python/py-astunparse
# py312-astunparse               @1.6.3          python/py-astunparse
# py-async_generator             @1.10           python/py-async_generator
# py-asyncmy                     @0.2.5          python/py-asyncmy
# py-asyncpg                     @0.29.0         python/py-asyncpg
# py39-asv                       @0.6.4          python/py-asv
# py310-asv                      @0.6.4          python/py-asv
# py311-asv                      @0.6.4          python/py-asv
# py312-asv                      @0.6.4          python/py-asv
# py313-asv                      @0.6.4          python/py-asv
# py39-asv-runner                @0.2.1          python/py-asv-runner
# py310-asv-runner               @0.2.1          python/py-asv-runner
# py311-asv-runner               @0.2.1          python/py-asv-runner
# py312-asv-runner               @0.2.1          python/py-asv-runner
# py313-asv-runner               @0.2.1          python/py-asv-runner
# py39-async-lru                 @2.0.5          python/py-async-lru
# py310-async-lru                @2.0.5          python/py-async-lru
# py311-async-lru                @2.0.5          python/py-async-lru
# py312-async-lru                @2.0.5          python/py-async-lru
# py313-async-lru                @2.0.5          python/py-async-lru
# py39-async-timeout             @4.0.3          python/py-async-timeout
# py310-async-timeout            @4.0.3          python/py-async-timeout
# py311-async-timeout            @4.0.3          python/py-async-timeout
# py313-async-timeout            @4.0.3          python/py-async-timeout
# py312-async-timeout            @4.0.3          python/py-async-timeout
# py39-async_generator           @1.10           python/py-async_generator
# py310-async_generator          @1.10           python/py-async_generator
# py311-async_generator          @1.10           python/py-async_generator
# py312-async_generator          @1.10           python/py-async_generator
# py313-async_generator          @1.10           python/py-async_generator
# py39-asyncmy                   @0.2.5          python/py-asyncmy
# py310-asyncmy                  @0.2.5          python/py-asyncmy
# py39-asyncpg                   @0.29.0         python/py-asyncpg
# py310-asyncpg                  @0.29.0         python/py-asyncpg
# py311-asyncpg                  @0.29.0         python/py-asyncpg
# py312-asyncpg                  @0.29.0         python/py-asyncpg
# py-asyncssh                    @2.21.0         python/py-asyncssh
# py-asynctest                   @0.13.0         python/py-asynctest
# py-atomiclong                  @0.1.1          python/py-atomiclong
# py-atomicwrites                @1.4.1          python/py-atomicwrites
# py-atpublic                    @2.3            python/py-atpublic
# py-atpy                        @0.9.7          python/py-atpy
# py-attr                        @0.3.2          python/py-attr
# py-attrs                       @25.3.0         python/py-attrs
# py-aubio                       @0.4.9          python/py-aubio
# py-audioop_lts                 @0.2.1          python/py-audioop_lts
# py-audioread                   @3.0.1          python/py-audioread
# py39-asyncssh                  @2.21.0         python/py-asyncssh
# ...
# py-yaspin                      @2.3.0          python/py-yaspin
# py-yenc                        @0.4.0          python/py-yenc
# py-yolk                        @0.4.3          python/py-yolk
# py-yt                          @3.5.1          python/py-yt
# py-yubico                      @1.3.3          python/py-yubico
# py-yum-metadata-parser         @1.1.4          python/py-yum-metadata-parser
# py-zbar                        @0.1.9          python/py-zbar
# py-zc-buildout                 @2.13.3         python/py-zc-buildout
# py39-yapf                      @0.43.0         python/py-yapf
# py310-yapf                     @0.43.0         python/py-yapf
# py311-yapf                     @0.43.0         python/py-yapf
# py312-yapf                     @0.43.0         python/py-yapf
# py313-yapf                     @0.43.0         python/py-yapf
# py312-yappi                    @1.6.10         python/py-yappi
# py37-yapsy                     @1.12.2         python/py-yapsy
# py39-yarl                      @1.20.0         python/py-yarl
# py310-yarl                     @1.20.0         python/py-yarl
# py311-yarl                     @1.20.0         python/py-yarl
# py312-yarl                     @1.20.0         python/py-yarl
# py313-yarl                     @1.20.0         python/py-yarl
# py39-yaspin                    @2.3.0          python/py-yaspin
# py310-yaspin                   @2.3.0          python/py-yaspin
# py311-yaspin                   @2.3.0          python/py-yaspin
# py27-yenc                      @0.4.0          python/py-yenc
# py27-yolk                      @0.4.3          python/py-yolk
# py312-yt                       @3.5.1          python/py-yt
# py310-yubico                   @1.3.3          python/py-yubico
# py311-yubico                   @1.3.3          python/py-yubico
# py312-yubico                   @1.3.3          python/py-yubico
# py27-yum-metadata-parser       @1.1.4          python/py-yum-metadata-parser
# py39-zbar                      @0.1.9          python/py-zbar
# py310-zbar                     @0.1.9          python/py-zbar
# py311-zbar                     @0.1.9          python/py-zbar
# py27-zc-buildout               @2.13.3         python/py-zc-buildout
# py-zc-lockfile                 @3.0.post1      python/py-zc-lockfile
# py-zconfig                     @3.5.0          python/py-zconfig
# py-zdaemon                     @4.3            python/py-zdaemon
# py-zeep                        @4.3.1          python/py-zeep
# py-zeroc-ice33                 @3.3.1          python/py-zeroc-ice33
# py-zeroc-ice34                 @3.4.2          python/py-zeroc-ice34
# py-zeroc-ice35                 @3.5.1          python/py-zeroc-ice35
# py27-zc-lockfile               @2.0            python/py-zc-lockfile
# py39-zc-lockfile               @3.0.post1      python/py-zc-lockfile
# py310-zc-lockfile              @3.0.post1      python/py-zc-lockfile
# py311-zc-lockfile              @3.0.post1      python/py-zc-lockfile
# py312-zc-lockfile              @3.0.post1      python/py-zc-lockfile
# py313-zc-lockfile              @3.0.post1      python/py-zc-lockfile
# py27-zconfig                   @3.5.0          python/py-zconfig
# py27-zdaemon                   @4.3            python/py-zdaemon
# py39-zeep                      @4.3.1          python/py-zeep
# py310-zeep                     @4.3.1          python/py-zeep
# py311-zeep                     @4.3.1          python/py-zeep
# py312-zeep                     @4.3.1          python/py-zeep
# py313-zeep                     @4.3.1          python/py-zeep
# py27-zeroc-ice33               @3.3.1          python/py-zeroc-ice33
# py27-zeroc-ice34               @3.4.2          python/py-zeroc-ice34
# py27-zeroc-ice35               @3.5.1          python/py-zeroc-ice35
# py-zict                        @3.0.0          python/py-zict
# py-zipfile-deflate64           @0.2.0          python/py-zipfile-deflate64
# py-zipp                        @3.21.0         python/py-zipp
# py-zipstream-ng                @1.8.0          python/py-zipstream-ng
# py-zlmdb                       @20.8.1         python/py-zlmdb
# py-zmq                         @25.1.2         python/py-zmq
# py-zodb                        @3.10.5         python/py-zodb
# py-zope-app-module             @3.5.0          python/py-zope-app-module
# py39-zict                      @3.0.0          python/py-zict
# py310-zict                     @3.0.0          python/py-zict
# py311-zict                     @3.0.0          python/py-zict
# py312-zict                     @3.0.0          python/py-zict
# py39-zipfile-deflate64         @0.2.0          python/py-zipfile-deflate64
# py310-zipfile-deflate64        @0.2.0          python/py-zipfile-deflate64
# py311-zipfile-deflate64        @0.2.0          python/py-zipfile-deflate64
# py312-zipfile-deflate64        @0.2.0          python/py-zipfile-deflate64
# py313-zipfile-deflate64        @0.2.0          python/py-zipfile-deflate64
# py27-zipp                      @1.2.0          python/py-zipp
# py35-zipp                      @1.2.0          python/py-zipp
# py36-zipp                      @3.6.0          python/py-zipp
# py37-zipp                      @3.15.0         python/py-zipp
# py38-zipp                      @3.20.2         python/py-zipp
# py39-zipp                      @3.21.0         python/py-zipp
# py310-zipp                     @3.21.0         python/py-zipp
# py311-zipp                     @3.21.0         python/py-zipp
# py312-zipp                     @3.21.0         python/py-zipp
# py313-zipp                     @3.21.0         python/py-zipp
# py39-zipstream-ng              @1.8.0          python/py-zipstream-ng
# py310-zipstream-ng             @1.8.0          python/py-zipstream-ng
# py311-zipstream-ng             @1.8.0          python/py-zipstream-ng
# py312-zipstream-ng             @1.8.0          python/py-zipstream-ng
# py313-zipstream-ng             @1.8.0          python/py-zipstream-ng
# py39-zlmdb                     @20.8.1         python/py-zlmdb
# py27-zmq                       @19.0.2         python/py-zmq
# py39-zmq                       @25.1.2         python/py-zmq
# py310-zmq                      @25.1.2         python/py-zmq
# py311-zmq                      @25.1.2         python/py-zmq
# py312-zmq                      @25.1.2         python/py-zmq
# py313-zmq                      @25.1.2         python/py-zmq
# py27-zodb                      @3.10.5         python/py-zodb
# py27-zope-app-module           @3.5.0          python/py-zope-app-module
# py-zope-component              @6.0            python/py-zope-component
# py-zope-configuration          @4.4.0          python/py-zope-configuration
# py-zope-deferredimport         @4.4            python/py-zope-deferredimport
# py-zope-deprecation            @5.0            python/py-zope-deprecation
# py-zope-event                  @5.0            python/py-zope-event
# py-zope-hookable               @5.4            python/py-zope-hookable
# py-zope-i18nmessageid          @5.0.1          python/py-zope-i18nmessageid
# py-zope-keyreference           @3.6.4          python/py-zope-keyreference
# py-zope-proxy                  @4.6.1          python/py-zope-proxy
# py-zope-schema                 @6.2.0          python/py-zope-schema
# py-zopeinterface               @7.2            python/py-zopeinterface
# py-zopfli                      @0.2.3.post1    python/py-zopfli
# py39-zope-component            @6.0            python/py-zope-component
# py310-zope-component           @6.0            python/py-zope-component
# py311-zope-component           @6.0            python/py-zope-component
# py312-zope-component           @6.0            python/py-zope-component
# py313-zope-component           @6.0            python/py-zope-component
# py39-zope-configuration        @4.4.0          python/py-zope-configuration
# py310-zope-configuration       @4.4.0          python/py-zope-configuration
# py39-zope-deferredimport       @4.4            python/py-zope-deferredimport
# py310-zope-deferredimport      @4.4            python/py-zope-deferredimport
# py39-zope-deprecation          @5.0            python/py-zope-deprecation
# py310-zope-deprecation         @5.0            python/py-zope-deprecation
# py311-zope-deprecation         @5.0            python/py-zope-deprecation
# py27-zope-event                @4.6            python/py-zope-event
# py37-zope-event                @5.0            python/py-zope-event
# py38-zope-event                @5.0            python/py-zope-event
# py39-zope-event                @5.0            python/py-zope-event
# py310-zope-event               @5.0            python/py-zope-event
# py311-zope-event               @5.0            python/py-zope-event
# py312-zope-event               @5.0            python/py-zope-event
# py313-zope-event               @5.0            python/py-zope-event
# py39-zope-hookable             @5.4            python/py-zope-hookable
# py310-zope-hookable            @5.4            python/py-zope-hookable
# py311-zope-hookable            @5.4            python/py-zope-hookable
# py312-zope-hookable            @5.4            python/py-zope-hookable
# py313-zope-hookable            @5.4            python/py-zope-hookable
# py39-zope-i18nmessageid        @5.0.1          python/py-zope-i18nmessageid
# py27-zope-keyreference         @3.6.4          python/py-zope-keyreference
# py39-zope-proxy                @4.6.1          python/py-zope-proxy
# py310-zope-proxy               @4.6.1          python/py-zope-proxy
# py39-zope-schema               @6.2.0          python/py-zope-schema
# py310-zope-schema              @6.2.0          python/py-zope-schema
# py311-zopeinterface            @7.2            python/py-zopeinterface
# py312-zopeinterface            @7.2            python/py-zopeinterface
# py310-zope-i18nmessageid       @5.0.1          python/py-zope-i18nmessageid
# py27-zopeinterface             @5.5.2          python/py-zopeinterface
# py35-zopeinterface             @5.5.2          python/py-zopeinterface
# py36-zopeinterface             @5.5.2          python/py-zopeinterface
# py37-zopeinterface             @6.4.post2      python/py-zopeinterface
# py38-zopeinterface             @7.2            python/py-zopeinterface
# py39-zopeinterface             @7.2            python/py-zopeinterface
# py310-zopeinterface            @7.2            python/py-zopeinterface
# py313-zopeinterface            @7.2            python/py-zopeinterface
# py39-zopfli                    @0.2.3.post1    python/py-zopfli
# py310-zopfli                   @0.2.3.post1    python/py-zopfli
# py311-zopfli                   @0.2.3.post1    python/py-zopfli
# py312-zopfli                   @0.2.3.post1    python/py-zopfli
# py313-zopfli                   @0.2.3.post1    python/py-zopfli
# py-zsi                         @2.0            python/py-zsi
# py-zstd                        @0.23.0         python/py-zstd
# py-zxcvbn                      @4.4.28         python/py-zxcvbn
# py27-atspi                     @0.4.1          python/py27-atspi
# py27-dulwich                   @0.19.16        python/py27-dulwich
# py27-gnome                     @2.28.1         python/py27-gnome
# py27-gobject3                  @3.36.1         python/py27-gobject3
# py27-gst-python                @0.10.22        python/py27-gst-python
# py27-matplotlib                @2.2.5          python/py27-matplotlib
# py27-numpy                     @1.16.6         python/py27-numpy
# py27-osmgpsmap                 @0.7.3          python/py27-osmgpsmap
# py27-pygtksourceview           @2.10.1         python/py27-pygtksourceview
# py27-zsi                       @2.0            python/py-zsi
# py39-zstd                      @0.23.0         python/py-zstd
# py310-zstd                     @0.23.0         python/py-zstd
# py311-zstd                     @0.23.0         python/py-zstd
# py312-zstd                     @0.23.0         python/py-zstd
# py313-zstd                     @0.23.0         python/py-zstd
# py310-zxcvbn                   @4.4.28         python/py-zxcvbn
# py311-zxcvbn                   @4.4.28         python/py-zxcvbn
# py312-zxcvbn                   @4.4.28         python/py-zxcvbn
# py27-pyobjc                    @5.3            python/py27-pyobjc
# py27-pyobjc-cocoa              @5.3            python/py27-pyobjc-cocoa
# py27-pyqt5                     @5.15.4         python/py27-pyqt5
# py27-scipy                     @1.2.3          python/py27-scipy
# py3c                           @1.4            python/py3c
# pycodestyle_select             @0.1            python/pycodestyle_select
# pydocstyle_select              @0.1            python/pydocstyle_select
# pyflakes_select                @0.1            python/pyflakes_select
# pygments_select                @0.1            python/pygments_select
# pylint_select                  @0.1            python/pylint_select
# pytest_select                  @0.1            python/pytest_select
# python-language-server_select  @0.1            python/python-language-server_select
# py35-pyobjc                    @5.3            python/py27-pyobjc
# py35-pyobjc-cocoa              @5.3            python/py27-pyobjc-cocoa
# py27-pyqt5-common              @5.15.4         python/py27-pyqt5
# py27-pyqt5-webengine           @5.15.5         python/py27-pyqt5
# py27-pyqt5-chart               @5.15.4         python/py27-pyqt5
# python-lsp-server_select       @0.1            python/python-lsp-server_select
# pyupgrade                      @3.20.0         python/pyupgrade
# quodlibet                      @4.5.0          python/quodlibet
# rdiff-backup                   @2.2.6          python/rdiff-backup
# refurb                         @2.1.0          python/refurb
# repo                           @2.32           python/repo
# scapy_select                   @0.1            python/scapy_select
# scrapy_select                  @0.1            python/scrapy_select
# sphinx_select                  @0.1            python/sphinx_select
# spyder_select                  @0.1            python/spyder_select
# stem_select                    @0.1            python/stem_select
# thefuck                        @3.32           python/thefuck
# tmuxp_select                   @0.1            python/tmuxp_select
# tox_select                     @0.1            python/tox_select
# trepan3k_select                @0.0            python/trepan3k_select
# trim_osc                       @20220518       python/trim_osc
# tubeup                         @2025.5.11      python/tubeup
# twine                          @6.1.0          python/twine
# virtualenv-clone_select        @0.1            python/virtualenv-clone_select
# virtualenv_select              @0.1            python/virtualenv_select
# virtualenvwrapper_select       @0.1            python/virtualenvwrapper_select
# vitables                       @3.1.0          python/vitables
# yapf_select                    @0.1            python/yapf_select
# python2_select                 @0.1            sysutils/python2_select
# python3_select                 @0.1            sysutils/python3_select
# python_select                  @0.3            sysutils/python_select
# python3_select-38              @0.1            sysutils/python3_select
# python3_select-39              @0.1            sysutils/python3_select
# python3_select-310             @0.1            sysutils/python3_select
# python3_select-311             @0.1            sysutils/python3_select
# python3_select-312             @0.1            sysutils/python3_select
# python_select-39               @0.3            sysutils/python_select
# python_select-311              @0.3            sysutils/python_select
# python_select-312              @0.3            sysutils/python_select
# python_select-313              @0.3            sysutils/python_select
# python_select-314              @0.3            sysutils/python_select
# python3_select-313             @0.1            sysutils/python3_select
# python3_select-314             @0.1            sysutils/python3_select
# python_select-38               @0.3            sysutils/python_select
# python_select-310              @0.3            sysutils/python_select
# mod_python                     @3.5.0          www/mod_python
# mod_python27                   @3.5.0          www/mod_python

# %%
# Jupyter Notebook for CDF File Analysis
# Replicating Mathematica workflow with Python

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from spacepy import pycdf
from IPython.display import display, Markdown

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 7
#       5 import numpy as np
#       6 import pandas as pd
# ----> 7 import matplotlib.pyplot as plt
#       8 from spacepy import pycdf
#       9 from IPython.display import display, Markdown
#
# ModuleNotFoundError: No module named 'matplotlib'
