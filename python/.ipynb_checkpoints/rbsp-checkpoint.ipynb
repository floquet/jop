# %%
# 1. Point to data
from pathlib import Path

dir_data = Path("/Users/dantopa/Mathematica_files/io/projects/hii-tsd/satellite/ecs/rbsp/data")
file_name_left = "rbspa_rel03_ect-rept-sci-L3_"
file_name_right = ".cdf"

# specific days
days = [
    "20170207_v5.1.0",
    "20170425_v5.5.0",
    "20170620_v5.3.0",
    "20170917_v5.3.0",
    "20171214_v5.3.0"
]

# 2. Pick one
my_file = dir_data / f"{file_name_left}{days[0]}{file_name_right}"
print(my_file)
# Out:
# /Users/dantopa/Mathematica_files/io/projects/hii-tsd/satellite/ecs/rbsp/data/rbspa_rel03_ect-rept-sci-L3_20170207_v5.1.0.cdf

# %%
# 1. Point to data
from pathlib import Path

dir_data = Path("/Users/dantopa/Mathematica_files/io/projects/hii-tsd/satellite/ecs/rbsp/data")
file_name_left = "rbspa_rel03_ect-rept-sci-L3_"
file_name_right = ".cdf"

# specific days
days = [
    "20170207_v5.1.0",
    "20170425_v5.5.0",
    "20170620_v5.3.0",
    "20170917_v5.3.0",
    "20171214_v5.3.0"
]

# 2. Pick one
my_file = dir_data / f"{file_name_left}{days[0]}{file_name_right}"
print(my_file)
# Out:
# /Users/dantopa/Mathematica_files/io/projects/hii-tsd/satellite/ecs/rbsp/data/rbspa_rel03_ect-rept-sci-L3_20170207_v5.1.0.cdf

# %%
import os
import pwd
import platform
import sys
import datetime

def pr_provenance():
    print("\n", datetime.datetime.now())
    print("source:  %s" % os.getcwd())  # __file__ may not be defined in Jupyter
    print("user id:", pwd.getpwuid(os.getuid()).pw_name)
    print("platform info:")
    print("    platform: ", platform.platform())
    print("    uname:    ", platform.uname())
    print("version info:")
    print("    python:   %s" % sys.version)
    print("    platform module version: (N/A in platform module)")
    return

pr_provenance()
# Out:
#  2025-06-18 10:34:30.563034
# source:  /Users/dantopa/repos-xiuhcoatl/github/jop/python
# user id: dantopa
# platform info:
#     platform:  macOS-15.5-x86_64-i386-64bit
#     uname:     uname_result(system='Darwin', node='Xiuhcoatl', release='24.5.0', version='Darwin Kernel Version 24.5.0: Tue Apr 22 19:53:26 PDT 2025; root:xnu-11417.121.6~2/RELEASE_X86_64', machine='x86_64')
# version info:
#     python:   3.12.11 (main, Jun  6 2025, 23:18:08) [Clang 16.0.0 (clang-1600.0.26.6)]
#     platform module version: (N/A in platform module)

# %% [markdown]
# # CDF File Exploration Notebook
#
# This notebook uses [`cdflib`](https://cdflib.readthedocs.io/) to explore NASA Common Data Format (.CDF) files.
#
# ## Features
#
# - Lists all variables (`rVariables` and `zVariables`)
# - Prints global and variable-specific attributes
# - Shows data previews with shape and value summaries
#
# Use this to inspect space physics data easily in Python.
#
# ---
#
# ## How It Works
#
# We open the CDF using:
#
# ```python
# cdf = cdflib.CDF(my_file)

# %% [markdown]
# # CDF File Exploration Notebook
#
# This notebook uses `cdflib` to explore NASA Common Data Format (.CDF) files.
#
# ## Features:
# - Lists all variables (rVariables and zVariables)
# - Prints global and variable-specific attributes
# - Shows data previews with shape info
#
# Use this to inspect space physics data easily in Python.
# How it works:
# We open the CDF with cdflib.CDF(my_file) and call cdf_info() to get overall metadata
# cdflib.readthedocs.io
# . This gives the file format version, encoding, majority, and lists of rVariable/zVariable names
# cdf-lib.readthedocs.io
# . We print those out, including any defined global dimensions (rDims). Next, we retrieve global attributes via globalattsget(), which returns a dictionary of attribute entries
# cdflib.readthedocs.io
# . Each attribute may have one or more entries (we loop to print each entry's value).
#
# For each variable, we get its info with varinq(), then determine its shape from the number of records and dimension sizes. We use varget() to fetch the first few data points
# cdflib.readthedocs.io
# (e.g., first 5 records) so we can show a sample of the values without overwhelming the output. Finally, we get the variable's attributes using varattsget(), which returns a dictionary of all attributes for that variable
# cdflib.readthedocs.io
# , and print them in a friendly format. The code handles edge cases like variables with no records (in which case varget might return nothing) and attributes that might be missing or None.
#
# Running this code in a Jupyter notebook will produce a well-organized readout of the CDF file's contents. It invites exploration by clearly displaying metadata and sample data. With this tool, colleagues can confidently inspect CDF files and appreciate that exploring space physics data in Python is accessible and fun.

# %%
import cdflib
import numpy as np

# Assume `my_file` is the path to the CDF file we want to explore.
# Load the CDF file into a cdflib CDF object.
cdf_file = cdflib.CDF(my_file)

# Get basic file information (version, encoding, majority, variables, etc.)
info = cdf_file.cdf_info()  # Returns a CDFInfo object/dictionary with file metadata:contentReference[oaicite:5]{index=5}:contentReference[oaicite:6]{index=6}

# Print high-level CDF file information
print("** CDF File Information **")
print(f"File path: {info.CDF}")
print(f"CDF Format Version: {info.Version}")
print(f"Encoding (Endianness code): {info.Encoding}")
print(f"Majority (Storage Order): {info.Majority}")  # e.g., 'Row_major' or 'Column_major':contentReference[oaicite:7]{index=7}

# If the file uses rVariables (common dimensions), display their count and sizes
if info.Num_rdim > 0:
    print(f"Number of rDimensions (global dimensions): {info.Num_rdim}")
    print(f"rDimension sizes: {info.rDim_sizes}")
else:
    print("Number of rDimensions: 0 (no global dimensional axes)")

# List all variable names
rvars = info.rVariables
zvars = info.zVariables
total_vars = len(rvars) + len(zvars)
print("\n** Variables in this CDF **")
print(f"Total variables: {total_vars} (rVariables: {len(rvars)}, zVariables: {len(zvars)})")
print(f"rVariables: {rvars if rvars else 'None'}")
print(f"zVariables: {zvars if zvars else 'None'}")

# Get all global attributes (returns a dict of {attribute: {entry: value}, ...} or empty dict if none):contentReference[oaicite:8]{index=8}
global_attrs = cdf_file.globalattsget()
print("\n** Global Attributes **")
if global_attrs:
    for attr, entries in global_attrs.items():
        # If an attribute has multiple entries, print each entry number and value
        if isinstance(entries, dict):
            # Multiple entries for this attribute
            print(f"- {attr}:")
            for entry_num, val in entries.items():
                print(f"    Entry {entry_num}: {val}")
        else:
            # In some cases globalattsget might return a simple value instead of dict
            print(f"- {attr}: {entries}")
else:
    print("(None)")

# Iterate over each variable (both rVariables and zVariables) to display details
all_vars = list(rvars) + list(zvars)
for var_name in all_vars:
    print(f"\n** Variable: {var_name} **")
    # Fetch variable info (datatype, dimensions, etc.)
    var_info = cdf_file.varinq(var_name)  # Basic variable info (VDRInfo) like num of records, dims, etc.
    # Determine the shape of the variable's data:
    rec_vary = bool(var_info.Rec_Vary)   # whether the variable varies by record (time)
    num_dims = var_info.Num_Dims
    dim_sizes = var_info.Dim_Sizes if var_info.Dim_Sizes is not None else []
    # Calculate number of records (if record-varying) or 1 if non-record-varying
    if rec_vary:
        n_records = var_info.Last_Rec + 1  # Last_Rec is 0-indexed; add 1 for count
    else:
        n_records = 1
    # Construct a shape tuple for display
    if rec_vary and num_dims > 0:
        shape = (n_records, *dim_sizes)
    elif rec_vary and num_dims == 0:
        shape = (n_records,)
    elif not rec_vary and num_dims > 0:
        shape = tuple(dim_sizes)
    else:
        shape = ()  # scalar
    print(f"Shape: {shape} (records x dimensions)" if shape else "Shape: scalar (single value)")

    # Retrieve a few sample data values from the variable.
    # If the variable has records, get the first few records; otherwise get the whole data (single record).
    try:
        if rec_vary:
            # Get first 5 records (or all if fewer than 5):contentReference[oaicite:9]{index=9}
            end_rec = min(var_info.Last_Rec, 4)  # 0-based index, so 0-4 = first 5 records
            data_preview = cdf_file.varget(var_name, startrec=0, endrec=end_rec)
        else:
            data_preview = cdf_file.varget(var_name)
    except Exception as e:
        # Handle case where varget fails (e.g., no data)
        data_preview = None
        print(f"Data: [Error reading data: {e}]")

    # Print first few values of the data_preview
    if data_preview is None:
        print("First values: None (no data available)")
    else:
        # Convert data to numpy array for easy shape and slicing, if it's not already an ndarray
        np_data = np.array(data_preview)
        # If data is multi-dimensional and large, flatten for preview
        if np_data.size > 10:
            flat = np_data.flatten()
            snippet = flat[:5]
            print(f"First values: {snippet} ...")
        else:
            # For small data, print as is
            print(f"Values: {np_data}")

    # Fetch variable-specific attributes (e.g., units, fill values):contentReference[oaicite:10]{index=10}
    var_attrs = cdf_file.varattsget(var_name)
    if var_attrs:
        print("Attributes:")
        for attr, val in var_attrs.items():
            # Some attributes might have no value (None)
            print(f"  - {attr}: {val}")
    else:
        print("Attributes: (none)")
# Out:
# ** CDF File Information **
# File path: /Users/dantopa/Dropbox/_mm/io/projects/hii-tsd/satellite/ecs/rbsp/data/rbspa_rel03_ect-rept-sci-L3_20170207_v5.1.0.cdf
# CDF Format Version: 3.7.0
# Encoding (Endianness code): 6
# Majority (Storage Order): Row_major
# Number of rDimensions: 0 (no global dimensional axes)
#
# ** Variables in this CDF **
# Total variables: 49 (rVariables: 0, zVariables: 49)
# rVariables: None
# zVariables: ['Epoch', 'Epoch_prot', 'FEDU_Alpha_DELTA', 'FEDU_Alpha', 'FEDU_0to180_Alpha', 'FEDU_180to360_Alpha', 'FPDU_Alpha', 'FPDU_0to180_Alpha', 'FPDU_180to360_Alpha', 'FEDU_Unbinned_Sector_Angle', 'FEDU_Unbinned_Alpha_DELTA', 'FEDU_Unbinned_Alpha', 'FEDU_Unbinned_Alpha360', 'FPDU_Unbinned_Sector_Angle', 'FPDU_Unbinned_Alpha_DELTA', 'FPDU_Unbinned_Alpha', 'FPDU_Unbinned_Alpha360', 'FEDU_Energy', 'FEDU_Energy_DELTA_minus', 'FEDU_Energy_DELTA_plus', 'FEDU_PA_LABL', 'FEDU_PA_0TO180_LABL', 'FEDU_PA_180TO360_LABL', 'FEDU_ENERGY_LABL', 'FEDU', 'FPDU_PA_LABL', 'FPDU_PA_0TO180_LABL', 'FPDU_PA_180TO360_LABL', 'FPDU_ENERGY_LABL', 'FPDU', 'FPDU_Energy', 'FEDU_0to180', 'FEDU_180to360', 'FPDU_0to180', 'FPDU_180to360', 'FEDU_Unbinned_0to180', 'FEDU_Unbinned_0to360', 'FPDU_Unbinned_0to180', 'FPDU_Unbinned_0to360', 'FPDU_Unbinned_LightMask_0to360', 'FPDU_Unbinned_Light_Flag', 'L_star', 'L', 'I', 'B_Calc', 'B_Eq', 'MLT', 'MLAT', 'Position']
#
# ** Global Attributes **
# - Project: ['LWS>Living With a Star']
# - Discipline: ['Space Physics>Magnetospheric Science']
# - Data_type: ['pre>Preliminary']
# - Descriptor: ['ect-rept-sci-L3>ECT REPT - Relativistic Electron Proton Telescope, Level 3 science data']
# - Logical_source_description: ['RBSP/ECT REPT Pitch Angle Resolved Electron and Proton Fluxes. Electron energies: 1.8 - 20 MeV. Proton energies: 21.25 - 4.791e+276 MeV']
# - TITLE: ['REPT (Relativistic Electron Proton Telescope), Level 3 science data']
# - TEXT: ['Van Allen Probes, RBSPECT/REPT (Radiation Belt Storm Probes Energetic particle, Composition and Thermal plasma suite/Relativistic Electron Proton Telescope, Level 3 Pitch Angle Sorted Data.']
# - Source_name: ['rbspa>Van Allen Probes, Radiation Belt Storm Probe A']
# - Logical_source: ['rbspa_relXX_ect-rept-sci-L3']
# - File_naming_convention: ['source_datatype_descriptor']
# - Data_version: ['03']
# - Software_version: ['4.0.0']
# - Command_line: ['/n/space_data/cda/rbsp/codes/rept/L2toL3/v4.0.0/REPT_L2_to_L3_v4_NMC_CentOS7 -b rbspa -e 17 -p 17 -S 20170207 -E 20170207 /n/space_data/cda/rbsp/rbspa/rept/level2/sci/int/2017/rbspa_int_ect-rept-sci-L2_20170207_v5.0.0.cdf /n/space_data/cda/rbsp/rbspa/MagEphem/definitive/2017/rbspa_def_MagEphem_OP77Q_20170207_v1.0.0.h5 /tmp/tmphPM6lk_run_rept_L2toL3_v4.0.0_metakern_20170207.kern /n/space_data/cda/rbsp/rbspa/emfisis/L2/2017/02/07/rbsp-a_magnetometer_uvw_emfisis-L2_20170207_v1.6.1.cdf /data/scratch/tmpErgfpH_rbspa_int_ect-rept-sci-L3_20170207_v5.1.0.cdf_runMe/rbspa_int_ect-rept-sci-L3_20170207_v5.1.0.cdf']
# - Command_line2: ['/n/space_data/cda/rbsp/codes/rept/L2toL3/v4.0.0/REPT_L2_to_L3_v4_NMC_CentOS7 -b rbspa -e 17 -p 17 -S 20170207 -E 20170207 /n/space_data/cda/rbsp/rbspa/rept/level2/sci/int/2017/rbspa_int_ect-rept-sci-L2_20170207_v5.0.0.cdf /n/space_data/cda/rbsp/rbspa/MagEphem/definitive/2017/rbspa_def_MagEphem_OP77Q_20170207_v1.0.0.h5 /tmp/tmphPM6lk_run_rept_L2toL3_v4.0.0_metakern_20170207.kern /n/space_data/cda/rbsp/rbspa/emfisis/L2/2017/02/07/rbsp-a_magnetometer_uvw_emfisis-L2_20170207_v1.6.1.cdf /data/scratch/tmpErgfpH_rbspa_int_ect-rept-sci-L3_20170207_v5.1.0.cdf_runMe/rbspa_int_ect-rept-sci-L3_20170207_v5.1.0.cdf']
# - PI_name: ['D. Baker']
# - PI_affiliation: ['University of Colorado at Boulder']
# - Instrument_type: ['Particles (space)']
# - Mission_group: ['Van Allen Probes (RBSP)']
# - Logical_file_id: ['/data/scratch/tmpErgfpH_rbspa_int_ect-rept-sci-L3_20170207_v5.1.0.cdf_runMe/rbspa_int_ect-rept-sci-L3_20170207_v5.1.0.cdf']
# - Time_resolution: ['0.298667 seconds per sector']
# - Rules_of_use: ['See Usage Guidelines at: http://www.rbsp-ect.lanl.gov/DataProductsUsage.php']
# - Generated_by: ['M. G. Henderson, Los Alamos National Laboratory, Van Allen Probes RBSP/ECT SOC (Science Operations Center)']
# - Generation_date: ['20170310']
# - Generation_datetime: ['2017-03-10T20:30:25Z']
# - Acknowledgement: ["This work was supported by Van Allen Probes/RBSP-ECT funding provided by JHU/APL Contract No. 967399 under NASA's Prime Contract No. NAS5-01072."]
# - MODS: [' ']
# - ADID_ref: [' ']
# - LINK_TEXT: ['Pitch-angle resolved REPT particle data available at']
# - LINK_TITLE: ['Van Allen Probes RBSP/ECT SOC (Science Operations Center)']
# - HTTP_LINK: ['http://www.rbsp-ect.lanl.gov/']
#
# ** Variable: Epoch **
# Shape: (8034,) (records x dimensions)
# Values: [6.36536448e+13 6.36536448e+13 6.36536448e+13 6.36536448e+13
#  6.36536448e+13]
# Attributes:
#   - CATDESC: Time since 0 AD
#   - FIELDNAM: Epoch
#   - MONOTON: INCREASE
#   - SCALETYP: linear
#   - VALIDMIN: 01-Jan-1990 00:00:00.000
#   - VALIDMAX: 31-Dec-2059 23:59:59.999
#   - FILLVAL: 31-Dec-9999 23:59:59.999
#   - VAR_NOTES: The midpoint of the sample time. Epoch, UTC.
#   - VAR_TYPE: support_data
#
# ** Variable: Epoch_prot **
# Shape: (8034,) (records x dimensions)
# Values: [6.36536448e+13 6.36536448e+13 6.36536448e+13 6.36536448e+13
#  6.36536448e+13]
# Attributes:
#   - CATDESC: Time since 0 AD
#   - FIELDNAM: Epoch_prot
#   - MONOTON: INCREASE
#   - SCALETYP: linear
#   - VALIDMIN: 01-Jan-1990 00:00:00.000
#   - VALIDMAX: 31-Dec-2059 23:59:59.999
#   - FILLVAL: 31-Dec-9999 23:59:59.999
#   - VAR_NOTES: Epoch for protons, UTC.
#   - VAR_TYPE: support_data
#
# ** Variable: FEDU_Alpha_DELTA **
# Shape: (17,) (records x dimensions)
# First values: [10.58823529 10.58823529 10.58823529 10.58823529 10.58823529] ...
# Attributes:
#   - CATDESC: FEDU_Alpha_DELTA
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#
# ** Variable: FEDU_Alpha **
# Shape: (17,) (records x dimensions)
# First values: [ 5.29411765 15.88235294 26.47058824 37.05882353 47.64705882] ...
# Attributes:
#   - CATDESC: Pitch angles for FEDU.
#   - FIELDNAM: FEDU_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. There are 17 pitch angle bins defined for electrons. The value is the center of each bin. These pitch angles range from 0 to 180 degrees.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FEDU_Alpha_DELTA
#   - DELTA_PLUS_VAR: FEDU_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Pitch Angle
#
# ** Variable: FEDU_0to180_Alpha **
# Shape: (17,) (records x dimensions)
# First values: [ 5.29411765 15.88235294 26.47058824 37.05882353 47.64705882] ...
# Attributes:
#   - CATDESC: Pitch angles for FEDU_0to180.
#   - FIELDNAM: FEDU_0to180_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. There are 17 pitch angle bins defined for electrons. The value is the center of each bin. These pitch angles range from 0 to 180 degrees.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FEDU_Alpha_DELTA
#   - DELTA_PLUS_VAR: FEDU_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Pitch Angle
#
# ** Variable: FEDU_180to360_Alpha **
# Shape: (17,) (records x dimensions)
# First values: [185.29411765 195.88235294 206.47058824 217.05882353 227.64705882] ...
# Attributes:
#   - CATDESC: Pitch angles for FEDU_180to360.
#   - FIELDNAM: FEDU_180to360_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 180.0
#   - VALIDMAX: 360.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. There are 17 pitch angle bins defined for electrons. The value is the center of each bin. These pitch angles range from 180 to 360 degrees.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FEDU_Alpha_DELTA
#   - DELTA_PLUS_VAR: FEDU_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Pitch Angle
#
# ** Variable: FPDU_Alpha **
# Shape: (17,) (records x dimensions)
# First values: [ 5.29411765 15.88235294 26.47058824 37.05882353 47.64705882] ...
# Attributes:
#   - CATDESC: Pitch angles for FPDU.
#   - FIELDNAM: FPDU_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. There are 17 pitch angle bins defined for protons. The value is the center of each bin. These pitch angles range from 0 to 180 degrees.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FPDU_Alpha_DELTA
#   - DELTA_PLUS_VAR: FPDU_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Pitch Angle
#
# ** Variable: FPDU_0to180_Alpha **
# Shape: (17,) (records x dimensions)
# First values: [ 5.29411765 15.88235294 26.47058824 37.05882353 47.64705882] ...
# Attributes:
#   - CATDESC: Pitch angles for FPDU_0to180.
#   - FIELDNAM: FPDU_0to180_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. There are 17 pitch angle bins defined for protons. The value is the center of each bin. These pitch angles range from 0 to 180 degrees.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FPDU_Alpha_DELTA
#   - DELTA_PLUS_VAR: FPDU_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Pitch Angle
#
# ** Variable: FPDU_180to360_Alpha **
# Shape: (17,) (records x dimensions)
# First values: [185.29411765 195.88235294 206.47058824 217.05882353 227.64705882] ...
# Attributes:
#   - CATDESC: Pitch angles for FPDU_180to360.
#   - FIELDNAM: FPDU_180to360_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 180.0
#   - VALIDMAX: 360.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. There are 17 pitch angle bins defined for protons. The value is the center of each bin. These pitch angles range from 180 to 360 degrees.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FPDU_Alpha_DELTA
#   - DELTA_PLUS_VAR: FPDU_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Pitch Angle
#
# ** Variable: FEDU_Unbinned_Sector_Angle **
# Shape: (0, 36) (records x dimensions)
# Data: [Error reading data: No records found for variable FEDU_Unbinned_Sector_Angle]
# First values: None (no data available)
# Attributes: (none)
#
# ** Variable: FEDU_Unbinned_Alpha_DELTA **
# Shape: (8034, 36) (records x dimensions)
# First values: [10. 10. 10. 10. 10.] ...
# Attributes:
#   - CATDESC: Pitch angle Deltas for FEDU_Unbinned.
#   - FIELDNAM: FEDU_Unbinned_Alpha_DELTA
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - LABLAXIS: Delta Alpha
#   - DEPEND_0: Epoch
#
# ** Variable: FEDU_Unbinned_Alpha **
# Shape: (8034, 36) (records x dimensions)
# First values: [18.81099703 25.37952847 33.62168549 42.53468177 51.80340163] ...
# Attributes:
#   - CATDESC: Pitch angles for FEDU_Unbinned.
#   - FIELDNAM: FEDU_Unbinned_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. This array provides for pitch angle tagging of the raw sector versus time arrays. The values are in the range 0-180 degrees. There are 36 sectors defined.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FEDU_Unbinned_Alpha_DELTA
#   - DELTA_PLUS_VAR: FEDU_Unbinned_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Alpha
#   - DEPEND_0: Epoch
#
# ** Variable: FEDU_Unbinned_Alpha360 **
# Shape: (8034, 36) (records x dimensions)
# First values: [18.81099703 25.37952847 33.62168549 42.53468177 51.80340163] ...
# Attributes:
#   - CATDESC: Pitch angles for FEDU_Unbinned360.
#   - FIELDNAM: FEDU_Unbinned_Alpha360
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 360.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. This array provides for pitch angle tagging of the raw sector versus time arrays. The values are in the range 0-360 degrees. There are 36 sectors defined.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FEDU_Unbinned_Alpha_DELTA
#   - DELTA_PLUS_VAR: FEDU_Unbinned_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: FEDU_Unbinned PitchAngle 0-360
#   - DEPEND_0: Epoch
#
# ** Variable: FPDU_Unbinned_Sector_Angle **
# Shape: (0, 36) (records x dimensions)
# Data: [Error reading data: No records found for variable FPDU_Unbinned_Sector_Angle]
# First values: None (no data available)
# Attributes: (none)
#
# ** Variable: FPDU_Unbinned_Alpha_DELTA **
# Shape: (8034, 36) (records x dimensions)
# First values: [10. 10. 10. 10. 10.] ...
# Attributes:
#   - CATDESC: Pitch angle Deltas for FPDU_Unbinned.
#   - FIELDNAM: FPDU_Unbinned_Alpha_DELTA
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - LABLAXIS: Delta Alpha
#   - DEPEND_0: Epoch_prot
#
# ** Variable: FPDU_Unbinned_Alpha **
# Shape: (8034, 36) (records x dimensions)
# First values: [18.81099703 25.37952847 33.62168549 42.53468177 51.80340163] ...
# Attributes:
#   - CATDESC: Pitch angle at center of each defined sector bin.
#   - FIELDNAM: FPDU_Unbinned_Alpha
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 180.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. This array provides for pitch angle tagging of the raw sector versus time arrays. The values are in the range 0-180 degrees. There are 36 sectors defined.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FPDU_Unbinned_Alpha_DELTA
#   - DELTA_PLUS_VAR: FPDU_Unbinned_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: Alpha
#   - DEPEND_0: Epoch_prot
#
# ** Variable: FPDU_Unbinned_Alpha360 **
# Shape: (8034, 36) (records x dimensions)
# First values: [18.81099703 25.37952847 33.62168549 42.53468177 51.80340163] ...
# Attributes:
#   - CATDESC: The center of each defined sector angle bin.
#   - FIELDNAM: FPDU_Unbinned_Alpha360
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 360.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Pitch angle, in degrees. This array provides for pitch angle tagging of the raw sector versus time arrays. The values are in the range 0-360 degrees. There are 36 sectors defined.
#   - VAR_TYPE: support_data
#   - UNITS: degrees
#   - DELTA_MINUS_VAR: FPDU_Unbinned_Alpha_DELTA
#   - DELTA_PLUS_VAR: FPDU_Unbinned_Alpha_DELTA
#   - FORMAT: E10.3
#   - LABLAXIS: FPDU_Unbinned PitchAngle 0-360
#   - DEPEND_0: Epoch_prot
#
# ** Variable: FEDU_Energy **
# Shape: (12,) (records x dimensions)
# First values: [1.8 2.1 2.6 3.4 4.2] ...
# Attributes:
#   - CATDESC: Energy centroids for FEDU
#   - FIELDNAM: FEDU_Energy
#   - SCALETYP: log
#   - FILLVAL: -1e+31
#   - VAR_NOTES: REPT energy channel centroids. These channels are the 12 main rate channels.
#   - VAR_TYPE: support_data
#   - UNITS: MeV
#   - DELTA_MINUS_VAR: FEDU_Energy_DELTA_minus
#   - DELTA_PLUS_VAR: FEDU_Energy_DELTA_plus
#   - FORMAT: E10.3
#   - LABLAXIS: Energy
#   - TYPICALMIN: 2.1
#   - TYPICALMAX: 20.0
#
# ** Variable: FEDU_Energy_DELTA_minus **
# Shape: (12,) (records x dimensions)
# First values: [0.0426  0.08655 0.17585 0.20545 0.4247 ] ...
# Attributes:
#   - CATDESC: FEDU_Energy_DELTA_minus
#   - FIELDNAM: FEDU_Energy_DELTA_minus
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 5000.0
#   - FILLVAL: -1e+31
#   - VAR_TYPE: support_data
#   - UNITS: MeV
#   - FORMAT: E12.2
#   - LABLAXIS: FEDU_Energy_DELTA_minus
#   - DEPEND_0: Epoch
#
# ** Variable: FEDU_Energy_DELTA_plus **
# Shape: (12,) (records x dimensions)
# First values: [0.0426  0.08655 0.17585 0.20545 0.4247 ] ...
# Attributes:
#   - CATDESC: FEDU_Energy_DELTA_plus
#   - FIELDNAM: FEDU_Energy_DELTA_plus
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 5000.0
#   - FILLVAL: -1e+31
#   - VAR_TYPE: support_data
#   - UNITS: MeV
#   - FORMAT: E12.2
#   - LABLAXIS: FEDU_Energy_DELTA_plus
#   - DEPEND_0: Epoch
#
# ** Variable: FEDU_PA_LABL **
# Shape: (1, 17) (records x dimensions)
# First values: ['5.29412 Degrees     ' '15.8824 Degrees     ' '26.4706 Degrees     '
#  '37.0588 Degrees     ' '47.6471 Degrees     '] ...
# Attributes:
#   - CATDESC: FEDU_PA_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FEDU_PA_0TO180_LABL **
# Shape: (1, 17) (records x dimensions)
# First values: ['5.29412 Degrees     ' '15.8824 Degrees     ' '26.4706 Degrees     '
#  '37.0588 Degrees     ' '47.6471 Degrees     '] ...
# Attributes:
#   - CATDESC: FEDU_PA_0TO180_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FEDU_PA_180TO360_LABL **
# Shape: (1, 17) (records x dimensions)
# First values: ['185.294 Degrees     ' '195.882 Degrees     ' '206.471 Degrees     '
#  '217.059 Degrees     ' '227.647 Degrees     '] ...
# Attributes:
#   - CATDESC: FEDU_PA_180TO360_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FEDU_ENERGY_LABL **
# Shape: (1, 12) (records x dimensions)
# First values: ['1.8 MeV             ' '2.1 MeV             ' '2.6 MeV             '
#  '3.4 MeV             ' '4.2 MeV             '] ...
# Attributes:
#   - CATDESC: FEDU_ENERGY_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FEDU **
# Shape: (8034, 17, 12) (records x dimensions)
# First values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31] ...
# Attributes:
#   - CATDESC: FEDU - Unidirectional Differential Electron Flux
#   - FIELDNAM: FEDU
#   - SCALETYP: log
#   - VALIDMIN: 1e-20
#   - VALIDMAX: 1e+31
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimension 0 holds 8034 time bins. Dimension 1 corresponds to 17 pitch angle bins.  Dimension 2 holds 12 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E12.2
#   - DEPEND_0: Epoch
#   - DEPEND_1: FEDU_Alpha
#   - DEPEND_2: FEDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - LABL_PTR_1: FEDU_PA_LABL
#   - LABL_PTR_2: FEDU_ENERGY_LABL
#
# ** Variable: FPDU_PA_LABL **
# Shape: (1, 17) (records x dimensions)
# First values: ['5.29412 Degrees     ' '15.8824 Degrees     ' '26.4706 Degrees     '
#  '37.0588 Degrees     ' '47.6471 Degrees     '] ...
# Attributes:
#   - CATDESC: FPDU_PA_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FPDU_PA_0TO180_LABL **
# Shape: (1, 17) (records x dimensions)
# First values: ['5.29412 Degrees     ' '15.8824 Degrees     ' '26.4706 Degrees     '
#  '37.0588 Degrees     ' '47.6471 Degrees     '] ...
# Attributes:
#   - CATDESC: FPDU_PA_0TO180_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FPDU_PA_180TO360_LABL **
# Shape: (1, 17) (records x dimensions)
# First values: ['185.294 Degrees     ' '195.882 Degrees     ' '206.471 Degrees     '
#  '217.059 Degrees     ' '227.647 Degrees     '] ...
# Attributes:
#   - CATDESC: FPDU_PA_180TO360_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FPDU_ENERGY_LABL **
# Shape: (1, 8) (records x dimensions)
# Values: [[['21.25 MeV           ']
#   ['27.6 MeV            ']
#   ['35.9 MeV            ']
#   ['46.7 MeV            ']
#   ['60.7 MeV            ']
#   ['78.9 MeV            ']
#   ['102.6 MeV           ']
#   ['208 MeV             ']]]
# Attributes:
#   - CATDESC: FPDU_ENERGY_LABL
#   - VAR_TYPE: support_data
#
# ** Variable: FPDU **
# Shape: (8034, 17, 8) (records x dimensions)
# First values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31] ...
# Attributes:
#   - CATDESC: FPDU - Unidirectional Differential Proton Flux
#   - FIELDNAM: FPDU
#   - SCALETYP: log
#   - VALIDMIN: 1e-20
#   - VALIDMAX: 1e+31
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimension 0 holds 8034 time bins. Dimension 1 corresponds to 17 pitch angle bins.  Dimension 2 holds 8 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E10.3
#   - DEPEND_0: Epoch_prot
#   - DEPEND_1: FPDU_Alpha
#   - DEPEND_2: FPDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - LABL_PTR_1: FPDU_PA_LABL
#   - LABL_PTR_2: FPDU_ENERGY_LABL
#
# ** Variable: FPDU_Energy **
# Shape: (1, 8) (records x dimensions)
# Values: [[ 21.25  27.6   35.9   46.7   60.7   78.9  102.6  208.  ]]
# Attributes:
#   - CATDESC: The channel or pixel number.
#   - FIELDNAM: FPDU_Energy
#   - SCALETYP: log
#   - VALIDMIN: 30.0
#   - VALIDMAX: 2500.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: REPT energy channel centroids. These channels are the 8 main rate channels.
#   - VAR_TYPE: support_data
#   - UNITS: MeV
#   - DELTA_MINUS_VAR: FPDU_Energy_DELTA_minus
#   - DELTA_PLUS_VAR: FPDU_Energy_DELTA_plus
#   - FORMAT: E10.3
#   - LABLAXIS: Energy
#
# ** Variable: FEDU_0to180 **
# Shape: (8034, 17, 12) (records x dimensions)
# First values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31] ...
# Attributes:
#   - CATDESC: FEDU - Unidirectional Differential Electron Flux
#   - FIELDNAM: FEDU_0to180
#   - SCALETYP: log
#   - VALIDMIN: 1e-20
#   - VALIDMAX: 1e+31
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 pitch angle bins. Dimension 2 holds 12 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E10.3
#   - DEPEND_0: Epoch
#   - DEPEND_1: FEDU_0to180_Alpha
#   - DEPEND_2: FEDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - LABL_PTR_1: FEDU_PA_0TO180_LABL
#   - LABL_PTR_2: FEDU_ENERGY_LABL
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FEDU_180to360 **
# Shape: (8034, 17, 12) (records x dimensions)
# First values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31] ...
# Attributes:
#   - CATDESC: FEDU - Unidirectional Differential Electron Flux
#   - FIELDNAM: FEDU_180to360
#   - SCALETYP: log
#   - VALIDMIN: 1e-20
#   - VALIDMAX: 1e+31
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 pitch angle bins. Dimension 2 holds 12 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E10.3
#   - DEPEND_0: Epoch
#   - DEPEND_1: FEDU_180to360_Alpha
#   - DEPEND_2: FEDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - LABL_PTR_1: FEDU_PA_180TO360_LABL
#   - LABL_PTR_2: FEDU_ENERGY_LABL
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FPDU_0to180 **
# Shape: (8034, 17, 8) (records x dimensions)
# First values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31] ...
# Attributes:
#   - CATDESC: FPDU - Unidirectional Differential Proton Flux
#   - FIELDNAM: FPDU_0to180
#   - SCALETYP: log
#   - VALIDMIN: 1e-20
#   - VALIDMAX: 1e+31
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 pitch angle bins. Dimension 2 holds 8 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E10.3
#   - DEPEND_0: Epoch_prot
#   - DEPEND_1: FPDU_0to180_Alpha
#   - DEPEND_2: FPDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - LABL_PTR_1: FPDU_PA_0TO180_LABL
#   - LABL_PTR_2: FPDU_ENERGY_LABL
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FPDU_180to360 **
# Shape: (8034, 17, 8) (records x dimensions)
# First values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31] ...
# Attributes:
#   - CATDESC: FPDU - Unidirectional Differential Proton Flux
#   - FIELDNAM: FPDU_180to360
#   - SCALETYP: log
#   - VALIDMIN: 1e-20
#   - VALIDMAX: 1e+31
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 pitch angle bins. Dimension 2 holds 8 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E10.3
#   - DEPEND_0: Epoch_prot
#   - DEPEND_1: FPDU_180to360_Alpha
#   - DEPEND_2: FPDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - LABL_PTR_1: FPDU_PA_180TO360_LABL
#   - LABL_PTR_2: FPDU_ENERGY_LABL
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FEDU_Unbinned_0to180 **
# Shape: (8034, 36, 12) (records x dimensions)
# First values: [284443.03686712 123991.06708285  40212.51451037   4496.94658723
#     460.18340728] ...
# Attributes:
#   - CATDESC: FEDU_Unbinned_0to180 - Unidirectional Differential Electron Flux (raw sector data).
#   - FIELDNAM: FEDU_Unbinned
#   - SCALETYP: log
#   - VALIDMIN: 0.0
#   - VALIDMAX: 1e+20
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 sector bins. Dimension 2 holds 12 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E12.2
#   - DEPEND_0: Epoch
#   - TYPICALMIN: 1.0
#   - TYPICALMAX: 1000000.0
#   - DEPEND_1: FEDU_Unbinned_Alpha
#   - DEPEND_2: FEDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FEDU_Unbinned_0to360 **
# Shape: (8034, 36, 12) (records x dimensions)
# First values: [284443.03686712 123991.06708285  40212.51451037   4496.94658723
#     460.18340728] ...
# Attributes:
#   - CATDESC: FEDU_Unbinned_0to360 - Unidirectional Differential Electron Flux (raw sector data).
#   - FIELDNAM: FEDU_Unbinned
#   - SCALETYP: log
#   - VALIDMIN: 0.0
#   - VALIDMAX: 1e+20
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 sector bins. Dimension 2 holds 12 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E12.2
#   - DEPEND_0: Epoch
#   - TYPICALMIN: 1.0
#   - TYPICALMAX: 1000000.0
#   - DEPEND_1: FEDU_Unbinned_Alpha360
#   - DEPEND_2: FEDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FPDU_Unbinned_0to180 **
# Shape: (8034, 36, 8) (records x dimensions)
# First values: [0. 0. 0. 0. 0.] ...
# Attributes:
#   - CATDESC: FPDU_Unbinned_0to180 - Unidirectional Differential Proton Flux (raw sector data).
#   - FIELDNAM: FPDU_Unbinned
#   - SCALETYP: log
#   - VALIDMIN: 0.0
#   - VALIDMAX: 1e+20
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 sector bins. Dimension 2 holds 8 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E12.2
#   - DEPEND_0: Epoch_prot
#   - TYPICALMIN: 1.0
#   - TYPICALMAX: 1000000.0
#   - DEPEND_1: FPDU_Unbinned_Alpha
#   - DEPEND_2: FPDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FPDU_Unbinned_0to360 **
# Shape: (8034, 36, 8) (records x dimensions)
# First values: [0. 0. 0. 0. 0.] ...
# Attributes:
#   - CATDESC: FPDU_Unbinned_0to360 - Unidirectional Differential Proton Flux (raw sector data).
#   - FIELDNAM: FPDU_Unbinned_0to360
#   - SCALETYP: log
#   - VALIDMIN: 0.0
#   - VALIDMAX: 1e+20
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 sector bins. Dimension 2 holds 8 energy bins.
#   - VAR_TYPE: data
#   - UNITS: cm!e-2!ns!e-1!nsr!e-1!nMeV!e-1!n
#   - FORMAT: E12.2
#   - DEPEND_0: Epoch_prot
#   - TYPICALMIN: 1.0
#   - TYPICALMAX: 1000000.0
#   - DEPEND_1: FPDU_Unbinned_Alpha360
#   - DEPEND_2: FPDU_Energy
#   - DISPLAY_TYPE: nnSpectrogram
#   - QUALITY_VAR: Data_Quality
#
# ** Variable: FPDU_Unbinned_LightMask_0to360 **
# Shape: (8034, 36) (records x dimensions)
# First values: [0 0 0 0 0] ...
# Attributes:
#   - CATDESC: FPDU_Unbinned_LightMask_0to360 - LightMask for FPDU_Unbinned_0to360 array.
#   - FIELDNAM: FPDU_Unbinned
#   - SCALETYP: linear
#   - VALIDMIN: 0
#   - VALIDMAX: 3
#   - FILLVAL: 0.0
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins. Dimension 1 holds 17 sector bins.
#   - VAR_TYPE: data
#   - UNITS: none
#   - DEPEND_0: Epoch_prot
#   - DEPEND_1: FPDU_Unbinned_Alpha360
#   - DISPLAY_TYPE: nnSpectrogram
#
# ** Variable: FPDU_Unbinned_Light_Flag **
# Shape: (8034,) (records x dimensions)
# Values: [0 0 0 0 0]
# Attributes:
#   - CATDESC: FPDU_Unbinned_Light_Flag
#   - FIELDNAM: FPDU_Unbinned_Light_Flag
#   - SCALETYP: linear
#   - VALIDMIN: 0
#   - VALIDMAX: 1
#   - FILLVAL: 0.0
#   - VAR_NOTES: Dimensions 0 holds 8034 time bins.
#   - VAR_TYPE: data
#   - UNITS: none
#   - DEPEND_0: Epoch_prot
#
# ** Variable: L_star **
# Shape: (8034,) (records x dimensions)
# Values: [4.0783478  4.07466345 4.07097944 4.06729509 4.06361108]
# Attributes:
#   - CATDESC: Lstar - Roederer's generalized L-shell parameter. Computed for 90deg. particles using OP77Q external field and IGRF internal field.
#   - FIELDNAM: L_star
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 10.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: L-shell parameters are dimensionless. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q.
#   - VAR_TYPE: data
#   - FORMAT: E10.3
#   - LABLAXIS: L!u*!n
#   - DEPEND_0: Epoch
#   - DISPLAY_TYPE: Series
#
# ** Variable: L **
# Shape: (8034,) (records x dimensions)
# Values: [4.27847091 4.27400704 4.26954358 4.26507971 4.26061626]
# Attributes:
#   - CATDESC: L - McIlwain's L-shell parameter. Computed for 90deg. particles using OP77Q external field and IGRF internal field.
#   - FIELDNAM: L
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 10.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: L-shell parameters are dimensionless. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q.
#   - VAR_TYPE: data
#   - FORMAT: E10.3
#   - LABLAXIS: L
#   - DEPEND_0: Epoch
#   - DISPLAY_TYPE: Series
#
# ** Variable: I **
# Shape: (8034,) (records x dimensions)
# Values: [0.15174311 0.15213054 0.15251793 0.15290536 0.15329276]
# Attributes:
#   - CATDESC: I - Integral invariant. Computed for 90deg. particles using OP77Q external field and IGRF internal field.
#   - FIELDNAM: I
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 10.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q.
#   - VAR_TYPE: data
#   - UNITS: R!dE!n
#   - FORMAT: E10.3
#   - LABLAXIS: I
#   - DEPEND_0: Epoch
#   - DISPLAY_TYPE: Series
#
# ** Variable: B_Calc **
# Shape: (8034,) (records x dimensions)
# Values: [401.26831527 402.60676007 403.94508038 405.28352518 406.6218455 ]
# Attributes:
#   - CATDESC: B_Calc - Magnitude of computed model field at the S/C. Computed using OP77Q external field and IGRF internal field.
#   - FIELDNAM: B_Calc
#   - SCALETYP: log
#   - VALIDMIN: 0.0
#   - VALIDMAX: 100000.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q.
#   - VAR_TYPE: data
#   - UNITS: nT
#   - FORMAT: E10.3
#   - LABLAXIS: B_Calc
#   - DEPEND_0: Epoch
#   - DISPLAY_TYPE: Series
#
# ** Variable: B_Eq **
# Shape: (8034,) (records x dimensions)
# Values: [378.50779307 379.70054827 380.89319253 382.08594773 383.278592  ]
# Attributes:
#   - CATDESC: B_Eq - Magnitude of computed model field at the Minimum-|B| point along the field line threading the S/C. Computed using OP77Q external field and IGRF internal field.
#   - FIELDNAM: B_Eq
#   - SCALETYP: log
#   - VALIDMIN: 0.0
#   - VALIDMAX: 100000.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q.
#   - VAR_TYPE: data
#   - UNITS: nT
#   - FORMAT: E10.3
#   - LABLAXIS: B_Eq
#   - DEPEND_0: Epoch
#   - DISPLAY_TYPE: Series
#
# ** Variable: MLT **
# Shape: (8034,) (records x dimensions)
# Values: [22.55269035 22.55699419 22.56129764 22.56560149 22.56990493]
# Attributes:
#   - CATDESC: MLT - Eccentric Dipole Magnetic Local Time. Computed using OP77Q external field and IGRF internal field.
#   - FIELDNAM: MLT
#   - SCALETYP: linear
#   - VALIDMIN: 0.0
#   - VALIDMAX: 24.0
#   - FILLVAL: -1e+31
#   - VAR_NOTES: Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q. Calculated with LANLGeomag library. Internal field: IGRF. External field: OP77Q.
#   - VAR_TYPE: data
#   - UNITS: hours
#   - FORMAT: E10.3
#   - LABLAXIS: MLT
#   - DEPEND_0: Epoch
#   - DISPLAY_TYPE: Series
#
# ** Variable: MLAT **
# Shape: (8034,) (records x dimensions)
# Values: [-3.87152124 -3.88083287 -3.89016731 -3.89952615 -3.90890751]
# Attributes:
#   - CATDESC: MLAT - Eccentric Dipole Magnetic Latitude. Computed using OP77Q external field and IGRF internal field.
#   - FIELDNAM: MLAT
#   - SCALETYP: linear
#   - VALIDMIN: -90.0
#   - VALIDMAX: 90.0
#   - FILLVAL: -1e+31
#   - VAR_TYPE: data
#   - UNITS: degrees
#   - FORMAT: E10.3
#   - LABLAXIS: MLAT
#   - DEPEND_0: Epoch
#   - DISPLAY_TYPE: Series
#
# ** Variable: Position **
# Shape: (8034, 3) (records x dimensions)
# First values: [24994.88245021 -4221.51110546 -3563.93064343 24970.54535714
#  -4208.51791174] ...
# Attributes:
#   - CATDESC: Position - Geocentric Geocentric position in Re.
#   - FIELDNAM: Position
#   - SCALETYP: linear
#   - VALIDMIN: -10.0
#   - VALIDMAX: 10.0
#   - FILLVAL: -1e+31
#   - VAR_TYPE: data
#   - UNITS: km
#   - FORMAT: E12.2
#   - DEPEND_0: Epoch
#   - TYPICALMIN: -6.0
#   - TYPICALMAX: 6.0
#   - DISPLAY_TYPE: series
#   - QUALITY_VAR: Data_Quality

# %%
import numpy as np
import cdflib
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from datetime import timedelta

# Load time and position data
times_raw = cdf_file.varget("Epoch")  # CDF_TIME_TT2000 format
positions = np.array(cdf_file.varget("Position"))  # Should be (N, 3)

# Convert to datetime objects
times = cdflib.cdfepoch.to_datetime(times_raw)

# Optional: limit to 24 hours from start
t0 = times[0]
t1 = t0 + np.timedelta64(24, 'h')
mask = (times >= t0) & (times <= t1)
positions_24h = positions[mask]
times_24h = np.array(times)[mask]

# %%
# Constants
G = 6.67430e-11  # m^3 kg^-1 s^-2
M_EARTH = 5.972e24  # kg
RE = 6371e3  # Earth radius in meters

# Convert position to meters
r_meters = positions_24h * 1e3  # from km to meters

# Estimate velocity using central differences (1st and last via forward/backward)
dt_seconds = np.median(np.diff(times_24h).astype('timedelta64[ns]').astype(float)) * 1e-9  # nanoseconds → seconds

v = np.zeros_like(r_meters)
v[1:-1] = (r_meters[2:] - r_meters[:-2]) / (2 * dt_seconds)
v[0] = (r_meters[1] - r_meters[0]) / dt_seconds
v[-1] = (r_meters[-1] - r_meters[-2]) / dt_seconds

# Energy calculations per unit mass
speed_squared = np.sum(v**2, axis=1)
r_norm = np.linalg.norm(r_meters, axis=1)

KE = 0.5 * speed_squared  # Kinetic energy per unit mass (J/kg)
PE = -G * M_EARTH / r_norm  # Potential energy per unit mass (J/kg)
TE = KE + PE  # Total mechanical energy per unit mass

# Plot energies
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(times_24h, KE / 1e6, label='Kinetic Energy [MJ/kg]')
ax.plot(times_24h, PE / 1e6, label='Potential Energy [MJ/kg]')
ax.plot(times_24h, TE / 1e6, label='Total Energy [MJ/kg]')

ax.set_title("Orbital Energy Over 24 Hours (per unit mass)")
ax.set_xlabel("Time (UTC)")
ax.set_ylabel("Energy (MegaJoules per kg)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Orbital Invariants: Angular Momentum and Laplace–Runge–Lenz Vector
#
# Given position $\vec{r}(t)$ and velocity $\vec{v}(t)$, we compute two conserved quantities for ideal two-body motion:
#
# ---
#
# **Angular Momentum Vector**
# $$
# \vec{h}(t) = \vec{r}(t) \times \vec{v}(t)
# $$
#
# ---
#
# **Laplace–Runge–Lenz (LRL) Vector**
# $$
# \vec{A}(t) = \vec{v}(t) \times \vec{h}(t) - \mu \frac{\vec{r}(t)}{\|\vec{r}(t)\|}
# $$
#
# where $\mu = GM$, Earth's gravitational parameter.
#
# ---
#
# These vectors are conserved in a Keplerian orbit:
# - $\vec{h}$ remains constant in direction and magnitude (fixed orbital plane).
# - $\vec{A}$ points toward periapsis and has magnitude proportional

# %%
mu = G * M_EARTH  # standard gravitational parameter

# Angular momentum h = r × v (in m^2/s)
h = np.cross(r_meters, v)

# Laplace–Runge–Lenz vector A = v × h - mu * r̂
r_hat = r_meters / r_norm[:, np.newaxis]
A = np.cross(v, h) - mu * r_hat  # in m^2/s^2

# Plot angular momentum components
fig, ax = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

ax[0].plot(times_24h, h[:, 0], label='h_x')
ax[0].plot(times_24h, h[:, 1], label='h_y')
ax[0].plot(times_24h, h[:, 2], label='h_z')
ax[0].set_ylabel("Angular Momentum (m²/s)")
ax[0].set_title("Angular Momentum Vector Components")
ax[0].legend()
ax[0].grid(True)

# Plot LRL vector components
ax[1].plot(times_24h, A[:, 0], label='A_x')
ax[1].plot(times_24h, A[:, 1], label='A_y')
ax[1].plot(times_24h, A[:, 2], label='A_z')
ax[1].set_ylabel("LRL Vector (m²/s²)")
ax[1].set_title("Laplace–Runge–Lenz Vector Components")
ax[1].set_xlabel("Time (UTC)")
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()
